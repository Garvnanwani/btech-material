# %%
import pandas as pd
import nltk
from nltk import word_tokenize
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/suryakant/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def clean_text(text):
  """Cleans the given text by removing stop words, punctuation, and normalizing the text.

  Args:
    text: The text to be cleaned.

  Returns:
    The cleaned text.
  """

  # Remove stop words.
  stop_words = nltk.corpus.stopwords.words("english")
  text = " ".join([word for word in text.split() if word not in stop_words])

  # Remove punctuation.
  text = text.replace(",", " ").replace(".", " ").replace("!", " ").replace("?", " ")

  # Normalize the text.
  text = text.lower()

  return text

# %%
if __name__ == "__main__":
   # Load the sms_spam.csv dataset.
  df = pd.read_csv("sms_spam.csv")

  # Clean the text in the dataset.
  df["text"] = df["text"].apply(clean_text)

  # Save the cleaned dataset to a new file.
  df.to_csv("sms_spam_cleaned.csv", index=False)

# %%
df
# Out:
#       type                                               text
# 0      ham  go jurong point  crazy   available bugis n gre...
# 1      ham                      ok lar    joking wif u oni
# 2     spam  free entry 2 wkly comp win fa cup final tkts 2...
# 3      ham          u dun say early hor    u c already say
# 4      ham          nah i think goes usf  lives around though
# ...    ...                                                ...
# 5569  spam  this 2nd time tried 2 contact u  u £750 pound ...
# 5570   ham                  will ü b going esplanade fr home
# 5571   ham           pity  * mood that  so   any suggestions
# 5572   ham  the guy bitching i acted like i'd interested b...
# 5573   ham                                rofl  its true name
#
# [5574 rows x 2 columns]

# %%
df = df.sample(frac=1, random_state=42)

# Split the data into a training set and a testing set
train_size = int(len(df) * 0.9)
train_df = df.head(train_size)
test_df = df.tail(len(df) - train_size)

# %%
train_df
# Out:
#      type                                               text
# 3690  ham                          you still coming tonight
# 3527  ham  "hey babe  far 2 spun-out 2 spk at da mo    de...
# 724   ham                              ya even cookies jelly
# 3370  ham  sorry i've gone place  i ll tomorrow  really s...
# 468   ham                              when going ride bike
# ...   ...                                                ...
# 1680  ham  today "song dedicated day  " which song u dedi...
# 499   ham               kate jackson rec center 7ish  right
# 5058  ham  hey next sun 1030 there's basic yoga course   ...
# 1856  ham                 k :)you girl waiting reception ah
# 1388  ham  hope ur head hurt 2 much   am ploughing way pi...
#
# [5016 rows x 2 columns]

# %%
test_df
# Out:
#       type                                               text
# 3719   ham      cool  do like swimming  i pool jacuzzi house
# 2386  spam  someone contacted dating service entered phone...
# 3236   ham                             yes  princess  toledo
# 1540   ham  you're sure i'm trying make xavier smoke i wan...
# 1217  spam      you 1 new voicemail  please call 08719181513
# ...    ...                                                ...
# 3772   ham  hi  wlcome back  wonder got eaten lion somethi...
# 5191  spam  ree entry 2 weekly comp chance win ipod  txt p...
# 5226   ham  "oh fuck  juswoke up in a bed on a boatin the ...
# 5390   ham           not much no fights  it was a good nite
# 860    ham                       did say somebody named tampa
#
# [558 rows x 2 columns]

# %%
spam={}
ham={}
for type1,sentence in train_df.iterrows():
    stri=sentence['text']
    tokens = nltk.word_tokenize(stri)
    if sentence['type'] == "spam":
        for token in tokens:
            if token in spam:
                spam[token] += 1
            else:
                spam[token]=1
    else:
        for token in tokens:
            if token in ham:
                ham[token] += 1
            else:
                ham[token]=1

# %%
all_words={}
for token in spam:
    if token in all_words:
                all_words[token] += 1
    else:
                 all_words[token]=1
for token in ham:
    if token in all_words:
                all_words[token] += 1
    else:
                all_words[token]=1

# %%
spam
# Out:
# {'free': 200,
#  'message': 29,
#  'activate': 4,
#  '500': 22,
#  'text': 106,
#  'messages': 11,
#  'replying': 5,
#  'word': 23,
#  'for': 32,
#  'terms': 6,
#  '&': 164,
#  'conditions': 3,
#  'visit': 6,
#  'www': 73,
#  '07781482378': 2,
#  'com': 46,
#  't-mobile': 3,
#  'customer': 46,
#  'may': 6,
#  'claim': 102,
#  'camera': 31,
#  'phone': 37,
#  'upgrade': 3,
#  'pay': 1,
#  'go': 24,
#  'sim': 2,
#  'card': 4,
#  'loyalty': 7,
#  'call': 309,
#  '0845': 3,
#  '021': 2,
#  '3680': 2,
#  'offer': 26,
#  'ends': 4,
#  '28thfeb': 1,
#  't': 66,
#  'c': 47,
#  "'s": 65,
#  'apply': 26,
#  'kit': 1,
#  'strip': 1,
#  '-': 54,
#  'billed': 2,
#  '150p': 21,
#  'netcollex': 4,
#  'ltd': 14,
#  'po': 30,
#  'box': 32,
#  '1013': 1,
#  'ig11': 1,
#  'oja': 1,
#  'urgent': 57,
#  'this': 35,
#  '2nd': 18,
#  'attempt': 20,
#  'contact': 51,
#  'u': 141,
#  'your': 73,
#  '£900': 7,
#  'prize': 87,
#  'yesterday': 3,
#  'still': 6,
#  'awaiting': 8,
#  'collection': 25,
#  'to': 79,
#  'now': 118,
#  '09061702893': 2,
#  'acl03530150pm': 2,
#  'germany': 3,
#  '1': 40,
#  'pence': 3,
#  'per': 41,
#  'minute': 7,
#  'fixed': 2,
#  'line': 33,
#  'via': 3,
#  'access': 7,
#  'number': 24,
#  '0844': 2,
#  '861': 2,
#  '85': 4,
#  'no': 38,
#  'prepayment': 2,
#  'direct': 9,
#  'lastest': 1,
#  'stereophonics': 1,
#  'marley': 1,
#  'dizzee': 1,
#  'racal': 1,
#  'libertines': 1,
#  'the': 24,
#  'strokes': 1,
#  'win': 51,
#  'nookii': 1,
#  'games': 15,
#  'flirt': 4,
#  'click': 5,
#  'themob': 5,
#  'wap': 9,
#  'bookmark': 1,
#  '82468': 2,
#  'entry': 23,
#  '2': 152,
#  'wkly': 13,
#  'comp': 9,
#  'fa': 4,
#  'cup': 4,
#  'final': 15,
#  'tkts': 3,
#  '21st': 2,
#  '2005': 3,
#  '87121': 4,
#  'receive': 31,
#  'question': 6,
#  '(': 44,
#  'std': 7,
#  'txt': 142,
#  'rate': 21,
#  ')': 53,
#  '08452810075over18': 2,
#  'dear': 14,
#  'subscriber': 3,
#  'ur': 132,
#  'draw': 35,
#  '4': 108,
#  '£100': 21,
#  'gift': 16,
#  'voucher': 12,
#  'b': 12,
#  'entered': 4,
#  'receipt': 2,
#  'correct': 3,
#  'ans': 3,
#  'when': 2,
#  'elvis': 1,
#  'presleys': 1,
#  'birthday': 1,
#  'answer': 8,
#  '80062': 3,
#  'i': 52,
#  "'d": 2,
#  'like': 12,
#  'tell': 14,
#  'deepest': 1,
#  'darkest': 1,
#  'fantasies': 6,
#  '09094646631': 1,
#  '60p/min': 4,
#  'stop': 107,
#  'texts': 16,
#  '08712460324': 8,
#  'nat': 3,
#  'moby': 4,
#  'pub': 2,
#  'quiz': 11,
#  'high': 2,
#  'street': 2,
#  'know': 19,
#  'new': 60,
#  'duchess': 2,
#  'cornwall': 2,
#  'be': 4,
#  'first': 6,
#  'name': 13,
#  '82277': 6,
#  'unsub': 7,
#  '£1': 29,
#  '50': 30,
#  '008704050406': 2,
#  'sp': 6,
#  'arrow': 1,
#  'someonone': 1,
#  'trying': 14,
#  'dating': 13,
#  'service': 49,
#  'find': 20,
#  'could': 6,
#  'mobile': 109,
#  'landline': 29,
#  '09064015307': 1,
#  'box334sk38ch': 2,
#  'hello': 4,
#  'orange': 27,
#  'month': 2,
#  'news': 9,
#  'sport': 4,
#  'plus': 6,
#  '10': 10,
#  '20': 6,
#  'photo': 3,
#  'reply': 90,
#  'yes': 14,
#  ':': 146,
#  'co': 44,
#  'uk/ow': 1,
#  'wamma': 1,
#  'get': 74,
#  'laid': 3,
#  'want': 24,
#  'real': 11,
#  'doggin': 1,
#  'locations': 4,
#  'sent': 8,
#  'join': 15,
#  'uks': 3,
#  'largest': 3,
#  'dogging': 9,
#  'network': 19,
#  'dogs': 1,
#  '69696': 2,
#  'nyt': 3,
#  'ec2a': 4,
#  '3lp': 3,
#  '50/msg': 2,
#  'someone': 9,
#  'contacted': 4,
#  'fancy': 8,
#  'you': 112,
#  '09111032124': 1,
#  'pobox12n146tf150p': 1,
#  'we': 32,
#  'last': 9,
#  'weekends': 4,
#  'shows': 29,
#  'guaranteed': 47,
#  '09061701939': 1,
#  'code': 27,
#  's89': 1,
#  'valid': 22,
#  '12hrs': 15,
#  'winner': 15,
#  'as': 11,
#  'valued': 11,
#  'selected': 23,
#  'receivea': 2,
#  'reward': 9,
#  '09061701461': 2,
#  'kl341': 2,
#  '12': 4,
#  'hours': 4,
#  'only': 28,
#  'had': 16,
#  '11': 6,
#  'months': 3,
#  'more': 10,
#  'r': 25,
#  'entitled': 7,
#  'update': 17,
#  'latest': 33,
#  'colour': 15,
#  'mobiles': 11,
#  '08002986030': 2,
#  'unique': 2,
#  'user': 8,
#  'id': 1,
#  '1172': 1,
#  'removal': 2,
#  'send': 63,
#  '87239': 4,
#  'services': 14,
#  '08708034412': 2,
#  'tried': 16,
#  'response': 1,
#  'nokia': 53,
#  'fone': 4,
#  'camcorder': 15,
#  'hit': 4,
#  '08000930705': 16,
#  'delivery': 20,
#  'gsoh': 1,
#  'good': 12,
#  'spam': 1,
#  'ladies': 3,
#  'male': 3,
#  'gigolo': 1,
#  'uk': 52,
#  'fastest': 2,
#  'growing': 2,
#  'mens': 1,
#  'club': 18,
#  'oncall': 1,
#  'mjzgroup': 1,
#  '08714342399': 1,
#  '2stop': 2,
#  'msg': 27,
#  '@': 23,
#  '50rcvd': 1,
#  'hmv': 10,
#  'bonus': 20,
#  'special': 6,
#  'pounds': 16,
#  'genuine': 3,
#  'vouchers': 20,
#  'won': 27,
#  'just': 29,
#  'easy': 12,
#  'questions': 6,
#  'play': 18,
#  '86688': 19,
#  'info': 12,
#  '100percent-real': 3,
#  'ringtone': 26,
#  '87131': 4,
#  'poly': 16,
#  'true': 3,
#  'tone': 39,
#  'help': 13,
#  '2814032': 1,
#  '16': 25,
#  '1st': 23,
#  'tones': 21,
#  '3x£150pw': 1,
#  'e£nd': 1,
#  '09066612661': 2,
#  'complementary': 1,
#  '*': 97,
#  'tenerife': 7,
#  'holiday': 30,
#  '£10': 10,
#  '000': 28,
#  'cash': 54,
#  'await': 18,
#  'sae': 20,
#  'cs': 37,
#  '3': 24,
#  'wa14': 1,
#  '2px': 1,
#  '150ppm': 30,
#  '18+': 17,
#  'sender': 1,
#  'hol': 1,
#  'awarded': 35,
#  'caller': 11,
#  '27/6/03': 1,
#  'our': 8,
#  '08714714011': 1,
#  'sunshine': 7,
#  'q': 3,
#  'top': 15,
#  'sony': 7,
#  'dvd': 5,
#  'player': 10,
#  'country': 3,
#  'liverpool': 2,
#  'played': 1,
#  'mid': 1,
#  'week': 43,
#  'ansr': 3,
#  'tyrone': 3,
#  '£2000': 19,
#  '10/06/03': 1,
#  'reach': 5,
#  '09066368753': 1,
#  'asap': 6,
#  '97n7qp': 1,
#  'guess': 5,
#  'what': 4,
#  'somebody': 2,
#  'secretly': 2,
#  'fancies': 2,
#  'wan': 12,
#  'na': 10,
#  'is': 14,
#  'give': 6,
#  'us': 9,
#  '09065394514': 1,
#  'from': 13,
#  'datebox1282essexcm61xn': 2,
#  '150p/min': 4,
#  '18': 25,
#  'xxxmobilemovieclub': 2,
#  'use': 8,
#  'credit': 8,
#  'link': 6,
#  'next': 11,
#  'here': 3,
#  '>': 21,
#  'http': 17,
#  '//wap': 1,
#  'n=qjkgighjjgcbl': 1,
#  'unlimited': 10,
#  'hardcore': 2,
#  'porn': 4,
#  '69200': 1,
#  '24': 2,
#  'hrs': 1,
#  'chrgd': 1,
#  '50p': 5,
#  'day': 16,
#  '2exit': 1,
#  'conacted': 1,
#  '09111030116': 1,
#  'pobox12n146tf15': 1,
#  '7250i': 3,
#  'auction': 15,
#  'take': 10,
#  'part': 9,
#  '86021': 5,
#  'hg/suite342/2lands': 7,
#  'row/w1jhl': 3,
#  '16+': 21,
#  'secret': 9,
#  'admirer': 9,
#  'looking': 9,
#  'make': 13,
#  'u-find': 8,
#  'reveal': 10,
#  'thinks': 9,
#  'special-call': 8,
#  '09058094565': 2,
#  'weekend': 6,
#  '£1000': 30,
#  'spanish': 2,
#  '09050000332': 1,
#  'rstm': 2,
#  'sw7': 2,
#  '3ss': 2,
#  'december': 4,
#  '11mths+': 4,
#  '08002986906': 3,
#  '£250': 12,
#  'weekly': 20,
#  'competition': 3,
#  '80086': 2,
#  'txttowin': 2,
#  'sex': 11,
#  'sexy': 14,
#  'pic': 11,
#  'jordan': 4,
#  'babe': 8,
#  '88600': 3,
#  'then': 2,
#  'every': 28,
#  'wk': 16,
#  'celeb': 3,
#  'pocketbabe': 3,
#  'pics': 11,
#  '£3/wk': 4,
#  '087016248': 1,
#  "'ve": 8,
#  'invited': 5,
#  'xchat': 5,
#  'chat': 42,
#  'important': 10,
#  'announcement': 4,
#  'freephone': 6,
#  '0800': 9,
#  '542': 2,
#  '0825': 1,
#  'tonight': 1,
#  'mob': 20,
#  'bt': 4,
#  'txting': 7,
#  'gravel': 1,
#  '69888': 2,
#  'nt': 1,
#  '31p': 1,
#  'asked': 4,
#  'shy': 1,
#  '09058091870': 1,
#  'revealed': 3,
#  'pobox84': 5,
#  'm26': 2,
#  '3uz': 2,
#  '£500': 17,
#  'award': 23,
#  'unclaimed': 1,
#  '09066368327': 1,
#  'closingdate04/09/02': 1,
#  'claimcode': 1,
#  'm39m51': 1,
#  '50pmmorefrommobile2bremoved-mobypobox734ls27yf': 1,
#  'great': 10,
#  'double': 17,
#  'mins': 33,
#  'best': 7,
#  'tariffs': 6,
#  'and': 2,
#  'phones': 12,
#  'mobileupd8': 16,
#  '08000839402': 15,
#  '2stoptxt': 3,
#  '2/2': 1,
#  '146tf150p': 1,
#  '5/9/03': 1,
#  'try': 7,
#  '09064019788': 1,
#  'box42wr29c': 1,
#  'thanks': 13,
#  'order': 12,
#  'reference': 3,
#  'x49': 2,
#  'charged': 9,
#  'should': 5,
#  'arrive': 5,
#  'please': 46,
#  '09065989182': 2,
#  'loans': 1,
#  'purpose': 3,
#  'even': 5,
#  'bad': 1,
#  'tenants': 3,
#  'welcome': 8,
#  'noworriesloans': 1,
#  '08717111821': 1,
#  'private': 17,
#  '2003': 12,
#  'account': 17,
#  'statement': 15,
#  '800': 11,
#  'un-redeemed': 11,
#  's': 16,
#  'm': 12,
#  'points': 15,
#  '08715203685': 1,
#  'identifier': 15,
#  'code:4xx26': 1,
#  'expires': 16,
#  '13/10/04': 1,
#  'taking': 1,
#  'survey': 1,
#  'however': 1,
#  'wish': 2,
#  'txts': 12,
#  '80160': 1,
#  'txt43': 1,
#  '447801259231': 2,
#  '09058094597': 2,
#  'mths': 4,
#  'camera/video': 2,
#  'keep': 5,
#  'same': 1,
#  'extra': 6,
#  'mins/texts': 1,
#  'banneduk': 1,
#  '89555': 3,
#  'see': 18,
#  'cost': 21,
#  'textoperator': 3,
#  'g696ga': 2,
#  'xxx': 10,
#  'call09050000327': 2,
#  'vote': 1,
#  'sing': 2,
#  'along': 1,
#  'stars': 1,
#  'karaoke': 1,
#  '09090900040': 1,
#  'listen': 2,
#  'extreme': 1,
#  'dirty': 1,
#  'live': 28,
#  'going': 4,
#  'on': 8,
#  'in': 9,
#  'office': 1,
#  'right': 3,
#  'total': 1,
#  'privacy': 1,
#  'one': 8,
#  'knows': 1,
#  '[': 3,
#  'sic': 1,
#  ']': 3,
#  'listening': 1,
#  '60p': 1,
#  'min': 14,
#  '24/7mp': 1,
#  '0870753331018+': 1,
#  '22': 1,
#  'days': 12,
#  'kick': 3,
#  'off': 2,
#  'euro2004': 4,
#  'kept': 3,
#  'date': 9,
#  'results': 3,
#  'daily': 4,
#  'removed': 1,
#  '83222': 3,
#  'sorry': 3,
#  'unsubscribe': 16,
#  'yet': 2,
#  'package': 1,
#  'term': 2,
#  '54': 1,
#  'weeks': 6,
#  'pls': 9,
#  'resubmit': 1,
#  'request': 1,
#  'expiry': 1,
#  'pass': 3,
#  '69669': 2,
#  'collect': 20,
#  'polyphonic': 5,
#  'ringtones': 8,
#  'normal': 1,
#  'gprs': 1,
#  'charges': 1,
#  'enjoy': 10,
#  'talk': 3,
#  'friends': 5,
#  'fall': 1,
#  'love': 10,
#  'worlds': 1,
#  'discreet': 2,
#  'vip': 4,
#  '83110': 1,
#  'meet': 6,
#  'cash-balance': 7,
#  'currently': 10,
#  'maximize': 7,
#  'cash-in': 7,
#  'hmv1': 1,
#  '150p/msg': 14,
#  'congrats': 8,
#  '3g': 5,
#  'videophones': 5,
#  'yours': 8,
#  '09063458130': 3,
#  'videochat': 5,
#  'wid': 5,
#  'mates': 11,
#  'java': 5,
#  'dload': 5,
#  'polyph': 3,
#  'music': 20,
#  'noline': 5,
#  'rentl': 5,
#  'bx420': 4,
#  'ip4': 5,
#  '5we': 5,
#  'dorothy': 1,
#  'kiefer': 1,
#  'bank': 1,
#  'granite': 1,
#  'issues': 1,
#  'strong-buy': 1,
#  'explosive': 1,
#  'pick': 1,
#  'members': 2,
#  'up': 1,
#  'over': 8,
#  '300': 4,
#  '%': 1,
#  'nasdaq': 1,
#  'symbol': 1,
#  'cdgt': 1,
#  'that': 2,
#  '$': 3,
#  '5': 9,
#  '00': 8,
#  'hi': 15,
#  'chloe': 1,
#  'smashed': 1,
#  'saturday': 7,
#  'night': 4,
#  'how': 3,
#  'missing': 1,
#  'me': 10,
#  'visionsms': 2,
#  '150p/text': 1,
#  'pleased': 3,
#  'advise': 3,
#  'following': 5,
#  'recent': 3,
#  'review': 3,
#  '£1500': 3,
#  '09066364589': 2,
#  'twinks': 1,
#  'bears': 2,
#  'scallies': 1,
#  'skins': 1,
#  'jocks': 1,
#  'calling': 4,
#  'do': 17,
#  "n't": 5,
#  'miss': 5,
#  'fun': 8,
#  '08712466669': 1,
#  '10p/min': 10,
#  'update_now': 2,
#  'xmas': 13,
#  'motorola': 11,
#  'sonyericsson': 5,
#  'bluetooth': 9,
#  '1000': 5,
#  'call2optout/f4q=': 1,
#  'tddnewsletter': 1,
#  'emc1': 1,
#  'thedailydraw': 1,
#  'helen': 1,
#  'dozens': 1,
#  'prizeswith': 1,
#  '8007': 16,
#  'no1': 6,
#  'getzed': 7,
#  'pobox': 10,
#  '36504': 5,
#  'w4': 1,
#  '5wq': 1,
#  'norm': 2,
#  '150p/tone': 5,
#  'starting': 4,
#  '87066': 13,
#  'tscs': 3,
#  'idew': 2,
#  'skillgame': 3,
#  '1winaweek': 3,
#  'age16': 6,
#  '150ppermesssubscription': 3,
#  'video': 25,
#  'movie': 2,
#  '89105': 1,
#  'its': 2,
#  'films': 2,
#  'ordered': 3,
#  'yrs': 3,
#  '09094100151': 1,
#  'calls': 10,
#  'cast': 1,
#  'vary': 5,
#  'provided': 3,
#  'aom': 2,
#  'gbp5/month': 1,
#  'box61': 1,
#  'm60': 1,
#  '1er': 1,
#  'ages': 1,
#  'okmail': 1,
#  'dave': 2,
#  'notice': 3,
#  '#': 6,
#  '5000': 4,
#  '09061743806': 2,
#  'tcs': 4,
#  'box326': 2,
#  'cw25wx': 4,
#  'eg': 9,
#  'real1': 1,
#  'pushbutton': 1,
#  'dontcha': 1,
#  'babygoodbye': 1,
#  'golddigger': 1,
#  'webeburnin': 1,
#  '6': 5,
#  'will': 5,
#  'dream': 3,
#  'partner': 3,
#  'soon': 3,
#  'career': 1,
#  'flyng': 1,
#  'start': 7,
#  'horo': 2,
#  'followed': 3,
#  'star': 2,
#  'sign': 2,
#  'e': 6,
#  'g': 10,
#  'aries': 1,
#  'darling': 2,
#  'today': 20,
#  'would': 3,
#  'dont': 9,
#  'look': 3,
#  '09061213237': 2,
#  '£5000': 19,
#  '177': 2,
#  'm227xy': 2,
#  'costa': 7,
#  'del': 9,
#  'sol': 7,
#  '09050090044': 6,
#  'toclaim': 6,
#  'tc': 6,
#  'pobox334': 6,
#  'stockport': 6,
#  'sk38xh': 7,
#  'cost£1': 6,
#  '50/pm': 6,
#  'max10mins': 6,
#  'fantasy': 5,
#  'football': 2,
#  'back': 22,
#  'tv': 6,
#  'sky': 6,
#  'gamestar': 2,
#  'active': 2,
#  '£250k': 2,
#  'team': 3,
#  'scoring': 2,
#  'starts': 4,
#  'register': 2,
#  'opt': 11,
#  'out': 11,
#  '88088': 2,
#  '09061790121': 3,
#  'land': 17,
#  '3030': 8,
#  '+123': 2,
#  'congratulations': 14,
#  '£1450': 3,
#  '09050002311': 2,
#  'b4280703': 2,
#  'cs/stop': 3,
#  'sms': 28,
#  '08718727868': 2,
#  'check': 4,
#  'choose': 10,
#  'videos': 1,
#  'shsex': 1,
#  'netun': 1,
#  'fgkslpopw': 1,
#  'fgkslpo': 1,
#  'handset': 6,
#  '750': 16,
#  'anytime': 10,
#  'half': 12,
#  'price': 16,
#  'rental': 11,
#  'tomorrow': 9,
#  'stay': 2,
#  '250': 4,
#  'british': 2,
#  'hotels': 2,
#  'nothing': 3,
#  '£350': 11,
#  'dial': 1,
#  '08712300220': 6,
#  'national': 12,
#  'bx526': 1,
#  'sw73ss': 2,
#  'official': 4,
#  'england': 8,
#  'flag': 7,
#  'yer': 3,
#  'tonights': 2,
#  'game': 7,
#  '84199': 3,
#  'optout': 5,
#  'eng': 3,
#  'box39822': 3,
#  'w111wx': 3,
#  'subscribed': 3,
#  'content': 13,
#  '£3': 11,
#  '82324': 1,
#  'helpline': 2,
#  '08706091795': 2,
#  '2004': 7,
#  '07xxxxxxxxx': 3,
#  '786': 4,
#  'unredeemed': 4,
#  '08719181259': 1,
#  'xxxxx': 1,
#  '26': 1,
#  '03': 1,
#  '05': 3,
#  'call2optout/hf8': 1,
#  'a': 18,
#  'picture': 1,
#  'also': 3,
#  '//alto18': 1,
#  'uk/wave/wave': 1,
#  'asp': 2,
#  'o=44345': 1,
#  'summers': 1,
#  'finally': 1,
#  'singles': 5,
#  'yr': 9,
#  'area': 8,
#  'matched': 1,
#  'summer': 7,
#  'help08714742804': 1,
#  'realize': 1,
#  '40': 2,
#  'years': 7,
#  "'ll": 2,
#  'thousands': 1,
#  'old': 2,
#  'running': 1,
#  'around': 2,
#  'tattoos': 1,
#  'recently': 2,
#  'unable': 2,
#  'so': 3,
#  '07090298926': 1,
#  're-schedule': 2,
#  'ref:9307622': 1,
#  'information': 8,
#  'o2': 6,
#  'lucky': 8,
#  'why': 7,
#  'log': 7,
#  'onto': 7,
#  '//www': 11,
#  'urawinner': 6,
#  'there': 7,
#  'fantastic': 6,
#  'surprise': 5,
#  'representative': 10,
#  'mila': 2,
#  'age23': 2,
#  'blonde': 2,
#  'guys': 6,
#  'mtalk': 2,
#  '69866': 2,
#  '30pp/txt': 2,
#  '5free': 2,
#  'increments': 2,
#  'help08718728876': 2,
#  'burger': 2,
#  'king': 2,
#  'footy': 1,
#  'stadium': 1,
#  'sept': 2,
#  'large': 1,
#  'super': 3,
#  'coca-cola': 1,
#  'walk': 1,
#  'gr8': 7,
#  'all': 3,
#  'mobs': 1,
#  '2u': 1,
#  'rply': 3,
#  'title': 1,
#  'breathe1': 1,
#  'titles': 1,
#  'crazyin': 1,
#  'sleepingwith': 1,
#  'finest': 1,
#  'ymca': 1,
#  'pobox365o4w45wq': 1,
#  '300p': 2,
#  '07742676969': 2,
#  '08719180248': 2,
#  '45239': 3,
#  'must': 4,
#  '89545': 2,
#  '4-tc': 2,
#  'biz': 6,
#  '2optout': 3,
#  '087187262701': 2,
#  '50gbp/mtmsg18': 2,
#  'txtauction': 6,
#  'time': 14,
#  'pound': 5,
#  '08712101358': 2,
#  '10p': 13,
#  'bt-national-rate': 7,
#  'funk': 1,
#  'tones2u': 1,
#  'original': 3,
#  'n': 7,
#  '3gbp': 3,
#  'operator': 13,
#  'rates': 8,
#  'ou': 1,
#  '40gb': 5,
#  'ipod': 9,
#  'mp3': 4,
#  '83355': 3,
#  'ibhltd': 3,
#  'ldnw15h': 3,
#  '150p/mtmsgrcvd18': 2,
#  'promotion': 1,
#  '8714714': 1,
#  'city': 2,
#  'break': 2,
#  '£200': 7,
#  'shopping': 7,
#  'spree': 6,
#  'store': 5,
#  '88039': 3,
#  'skilgme': 3,
#  'tscs087147403231winawk': 2,
#  '50perwksub': 2,
#  '078498': 1,
#  '7': 4,
#  '08719180219': 1,
#  '06': 2,
#  '8077': 2,
#  'w45wq': 4,
#  'norm150p/tone': 4,
#  'rayman': 1,
#  'golf': 1,
#  'arcade': 4,
#  'settings': 2,
#  'post': 4,
#  'save': 3,
#  'activ8': 1,
#  'press': 2,
#  '0': 2,
#  'key': 1,
#  'termsapply': 1,
#  'reminder': 2,
#  'downloaded': 1,
#  'already': 1,
#  'paid': 1,
#  'goto': 5,
#  ...}

# %%
all_words
# Out:
# {'free': 2,
#  'message': 2,
#  'activate': 1,
#  '500': 1,
#  'text': 2,
#  'messages': 2,
#  'replying': 2,
#  'word': 2,
#  'for': 2,
#  'terms': 2,
#  '&': 2,
#  'conditions': 2,
#  'visit': 2,
#  'www': 2,
#  '07781482378': 1,
#  'com': 2,
#  't-mobile': 1,
#  'customer': 2,
#  'may': 2,
#  'claim': 1,
#  'camera': 2,
#  'phone': 2,
#  'upgrade': 1,
#  'pay': 2,
#  'go': 2,
#  'sim': 2,
#  'card': 2,
#  'loyalty': 1,
#  'call': 2,
#  '0845': 1,
#  '021': 1,
#  '3680': 1,
#  'offer': 2,
#  'ends': 2,
#  '28thfeb': 1,
#  't': 2,
#  'c': 2,
#  "'s": 2,
#  'apply': 2,
#  'kit': 1,
#  'strip': 1,
#  '-': 2,
#  'billed': 1,
#  '150p': 1,
#  'netcollex': 1,
#  'ltd': 1,
#  'po': 2,
#  'box': 2,
#  '1013': 1,
#  'ig11': 1,
#  'oja': 1,
#  'urgent': 2,
#  'this': 2,
#  '2nd': 2,
#  'attempt': 2,
#  'contact': 2,
#  'u': 2,
#  'your': 2,
#  '£900': 1,
#  'prize': 1,
#  'yesterday': 2,
#  'still': 2,
#  'awaiting': 1,
#  'collection': 1,
#  'to': 2,
#  'now': 2,
#  '09061702893': 1,
#  'acl03530150pm': 1,
#  'germany': 1,
#  '1': 2,
#  'pence': 1,
#  'per': 2,
#  'minute': 2,
#  'fixed': 2,
#  'line': 2,
#  'via': 2,
#  'access': 2,
#  'number': 2,
#  '0844': 1,
#  '861': 1,
#  '85': 1,
#  'no': 2,
#  'prepayment': 1,
#  'direct': 2,
#  'lastest': 1,
#  'stereophonics': 1,
#  'marley': 1,
#  'dizzee': 1,
#  'racal': 1,
#  'libertines': 1,
#  'the': 2,
#  'strokes': 1,
#  'win': 2,
#  'nookii': 1,
#  'games': 2,
#  'flirt': 2,
#  'click': 2,
#  'themob': 1,
#  'wap': 1,
#  'bookmark': 1,
#  '82468': 1,
#  'entry': 1,
#  '2': 2,
#  'wkly': 1,
#  'comp': 2,
#  'fa': 1,
#  'cup': 2,
#  'final': 2,
#  'tkts': 1,
#  '21st': 2,
#  '2005': 1,
#  '87121': 1,
#  'receive': 2,
#  'question': 2,
#  '(': 2,
#  'std': 1,
#  'txt': 2,
#  'rate': 2,
#  ')': 2,
#  '08452810075over18': 1,
#  'dear': 2,
#  'subscriber': 1,
#  'ur': 2,
#  'draw': 2,
#  '4': 2,
#  '£100': 1,
#  'gift': 2,
#  'voucher': 2,
#  'b': 2,
#  'entered': 2,
#  'receipt': 2,
#  'correct': 2,
#  'ans': 2,
#  'when': 2,
#  'elvis': 1,
#  'presleys': 1,
#  'birthday': 2,
#  'answer': 2,
#  '80062': 1,
#  'i': 2,
#  "'d": 2,
#  'like': 2,
#  'tell': 2,
#  'deepest': 1,
#  'darkest': 1,
#  'fantasies': 1,
#  '09094646631': 1,
#  '60p/min': 1,
#  'stop': 2,
#  'texts': 2,
#  '08712460324': 1,
#  'nat': 1,
#  'moby': 1,
#  'pub': 2,
#  'quiz': 1,
#  'high': 2,
#  'street': 2,
#  'know': 2,
#  'new': 2,
#  'duchess': 1,
#  'cornwall': 2,
#  'be': 2,
#  'first': 2,
#  'name': 2,
#  '82277': 1,
#  'unsub': 1,
#  '£1': 1,
#  '50': 2,
#  '008704050406': 1,
#  'sp': 1,
#  'arrow': 1,
#  'someonone': 1,
#  'trying': 2,
#  'dating': 1,
#  'service': 2,
#  'find': 2,
#  'could': 2,
#  'mobile': 2,
#  'landline': 2,
#  '09064015307': 1,
#  'box334sk38ch': 1,
#  'hello': 2,
#  'orange': 2,
#  'month': 2,
#  'news': 2,
#  'sport': 2,
#  'plus': 2,
#  '10': 2,
#  '20': 2,
#  'photo': 2,
#  'reply': 2,
#  'yes': 2,
#  ':': 2,
#  'co': 2,
#  'uk/ow': 1,
#  'wamma': 1,
#  'get': 2,
#  'laid': 2,
#  'want': 2,
#  'real': 2,
#  'doggin': 1,
#  'locations': 1,
#  'sent': 2,
#  'join': 2,
#  'uks': 1,
#  'largest': 1,
#  'dogging': 1,
#  'network': 2,
#  'dogs': 1,
#  '69696': 1,
#  'nyt': 2,
#  'ec2a': 1,
#  '3lp': 1,
#  '50/msg': 1,
#  'someone': 2,
#  'contacted': 1,
#  'fancy': 2,
#  'you': 2,
#  '09111032124': 1,
#  'pobox12n146tf150p': 1,
#  'we': 2,
#  'last': 2,
#  'weekends': 2,
#  'shows': 2,
#  'guaranteed': 1,
#  '09061701939': 1,
#  'code': 1,
#  's89': 1,
#  'valid': 1,
#  '12hrs': 1,
#  'winner': 1,
#  'as': 2,
#  'valued': 2,
#  'selected': 2,
#  'receivea': 1,
#  'reward': 1,
#  '09061701461': 1,
#  'kl341': 1,
#  '12': 2,
#  'hours': 2,
#  'only': 2,
#  'had': 2,
#  '11': 2,
#  'months': 2,
#  'more': 2,
#  'r': 2,
#  'entitled': 1,
#  'update': 2,
#  'latest': 2,
#  'colour': 2,
#  'mobiles': 1,
#  '08002986030': 1,
#  'unique': 2,
#  'user': 2,
#  'id': 2,
#  '1172': 1,
#  'removal': 1,
#  'send': 2,
#  '87239': 1,
#  'services': 2,
#  '08708034412': 1,
#  'tried': 2,
#  'response': 2,
#  'nokia': 2,
#  'fone': 2,
#  'camcorder': 1,
#  'hit': 2,
#  '08000930705': 1,
#  'delivery': 2,
#  'gsoh': 1,
#  'good': 2,
#  'spam': 1,
#  'ladies': 2,
#  'male': 1,
#  'gigolo': 1,
#  'uk': 1,
#  'fastest': 1,
#  'growing': 1,
#  'mens': 1,
#  'club': 1,
#  'oncall': 1,
#  'mjzgroup': 1,
#  '08714342399': 1,
#  '2stop': 1,
#  'msg': 2,
#  '@': 2,
#  '50rcvd': 1,
#  'hmv': 1,
#  'bonus': 1,
#  'special': 2,
#  'pounds': 2,
#  'genuine': 1,
#  'vouchers': 1,
#  'won': 1,
#  'just': 2,
#  'easy': 2,
#  'questions': 2,
#  'play': 2,
#  '86688': 1,
#  'info': 2,
#  '100percent-real': 1,
#  'ringtone': 1,
#  '87131': 1,
#  'poly': 1,
#  'true': 2,
#  'tone': 1,
#  'help': 2,
#  '2814032': 1,
#  '16': 2,
#  '1st': 2,
#  'tones': 1,
#  '3x£150pw': 1,
#  'e£nd': 1,
#  '09066612661': 1,
#  'complementary': 1,
#  '*': 2,
#  'tenerife': 1,
#  'holiday': 2,
#  '£10': 1,
#  '000': 1,
#  'cash': 2,
#  'await': 2,
#  'sae': 1,
#  'cs': 1,
#  '3': 2,
#  'wa14': 1,
#  '2px': 1,
#  '150ppm': 1,
#  '18+': 1,
#  'sender': 2,
#  'hol': 2,
#  'awarded': 1,
#  'caller': 2,
#  '27/6/03': 1,
#  'our': 2,
#  '08714714011': 1,
#  'sunshine': 2,
#  'q': 2,
#  'top': 2,
#  'sony': 2,
#  'dvd': 2,
#  'player': 2,
#  'country': 2,
#  'liverpool': 1,
#  'played': 2,
#  'mid': 2,
#  'week': 2,
#  'ansr': 1,
#  'tyrone': 1,
#  '£2000': 1,
#  '10/06/03': 1,
#  'reach': 2,
#  '09066368753': 1,
#  'asap': 2,
#  '97n7qp': 1,
#  'guess': 2,
#  'what': 2,
#  'somebody': 2,
#  'secretly': 1,
#  'fancies': 1,
#  'wan': 2,
#  'na': 2,
#  'is': 2,
#  'give': 2,
#  'us': 2,
#  '09065394514': 1,
#  'from': 2,
#  'datebox1282essexcm61xn': 1,
#  '150p/min': 1,
#  '18': 1,
#  'xxxmobilemovieclub': 1,
#  'use': 2,
#  'credit': 2,
#  'link': 2,
#  'next': 2,
#  'here': 2,
#  '>': 2,
#  'http': 1,
#  '//wap': 1,
#  'n=qjkgighjjgcbl': 1,
#  'unlimited': 2,
#  'hardcore': 2,
#  'porn': 1,
#  '69200': 1,
#  '24': 1,
#  'hrs': 2,
#  'chrgd': 1,
#  '50p': 1,
#  'day': 2,
#  '2exit': 1,
#  'conacted': 1,
#  '09111030116': 1,
#  'pobox12n146tf15': 1,
#  '7250i': 1,
#  'auction': 2,
#  'take': 2,
#  'part': 2,
#  '86021': 1,
#  'hg/suite342/2lands': 1,
#  'row/w1jhl': 1,
#  '16+': 1,
#  'secret': 2,
#  'admirer': 1,
#  'looking': 2,
#  'make': 2,
#  'u-find': 1,
#  'reveal': 1,
#  'thinks': 2,
#  'special-call': 1,
#  '09058094565': 1,
#  'weekend': 2,
#  '£1000': 1,
#  'spanish': 2,
#  '09050000332': 1,
#  'rstm': 1,
#  'sw7': 1,
#  '3ss': 1,
#  'december': 1,
#  '11mths+': 1,
#  '08002986906': 1,
#  '£250': 1,
#  'weekly': 1,
#  'competition': 2,
#  '80086': 1,
#  'txttowin': 1,
#  'sex': 2,
#  'sexy': 2,
#  'pic': 2,
#  'jordan': 2,
#  'babe': 2,
#  '88600': 1,
#  'then': 2,
#  'every': 2,
#  'wk': 2,
#  'celeb': 1,
#  'pocketbabe': 1,
#  'pics': 2,
#  '£3/wk': 1,
#  '087016248': 1,
#  "'ve": 2,
#  'invited': 2,
#  'xchat': 1,
#  'chat': 2,
#  'important': 2,
#  'announcement': 1,
#  'freephone': 1,
#  '0800': 1,
#  '542': 1,
#  '0825': 1,
#  'tonight': 2,
#  'mob': 1,
#  'bt': 2,
#  'txting': 2,
#  'gravel': 1,
#  '69888': 1,
#  'nt': 2,
#  '31p': 1,
#  'asked': 2,
#  'shy': 2,
#  '09058091870': 1,
#  'revealed': 1,
#  'pobox84': 1,
#  'm26': 1,
#  '3uz': 1,
#  '£500': 1,
#  'award': 2,
#  'unclaimed': 1,
#  '09066368327': 1,
#  'closingdate04/09/02': 1,
#  'claimcode': 1,
#  'm39m51': 1,
#  '50pmmorefrommobile2bremoved-mobypobox734ls27yf': 1,
#  'great': 2,
#  'double': 2,
#  'mins': 2,
#  'best': 2,
#  'tariffs': 1,
#  'and': 2,
#  'phones': 2,
#  'mobileupd8': 1,
#  '08000839402': 1,
#  '2stoptxt': 1,
#  '2/2': 1,
#  '146tf150p': 1,
#  '5/9/03': 1,
#  'try': 2,
#  '09064019788': 1,
#  'box42wr29c': 1,
#  'thanks': 2,
#  'order': 2,
#  'reference': 2,
#  'x49': 1,
#  'charged': 1,
#  'should': 2,
#  'arrive': 2,
#  'please': 2,
#  '09065989182': 1,
#  'loans': 2,
#  'purpose': 1,
#  'even': 2,
#  'bad': 2,
#  'tenants': 1,
#  'welcome': 2,
#  'noworriesloans': 1,
#  '08717111821': 1,
#  'private': 2,
#  '2003': 1,
#  'account': 2,
#  'statement': 2,
#  '800': 1,
#  'un-redeemed': 1,
#  's': 2,
#  'm': 2,
#  'points': 2,
#  '08715203685': 1,
#  'identifier': 1,
#  'code:4xx26': 1,
#  'expires': 1,
#  '13/10/04': 1,
#  'taking': 2,
#  'survey': 2,
#  'however': 2,
#  'wish': 2,
#  'txts': 1,
#  '80160': 1,
#  'txt43': 1,
#  '447801259231': 1,
#  '09058094597': 1,
#  'mths': 2,
#  'camera/video': 1,
#  'keep': 2,
#  'same': 2,
#  'extra': 2,
#  'mins/texts': 1,
#  'banneduk': 1,
#  '89555': 1,
#  'see': 2,
#  'cost': 2,
#  'textoperator': 1,
#  'g696ga': 1,
#  'xxx': 2,
#  'call09050000327': 1,
#  'vote': 2,
#  'sing': 2,
#  'along': 2,
#  'stars': 2,
#  'karaoke': 2,
#  '09090900040': 1,
#  'listen': 2,
#  'extreme': 1,
#  'dirty': 2,
#  'live': 2,
#  'going': 2,
#  'on': 2,
#  'in': 2,
#  'office': 2,
#  'right': 2,
#  'total': 2,
#  'privacy': 2,
#  'one': 2,
#  'knows': 2,
#  '[': 2,
#  'sic': 1,
#  ']': 2,
#  'listening': 2,
#  '60p': 1,
#  'min': 2,
#  '24/7mp': 1,
#  '0870753331018+': 1,
#  '22': 2,
#  'days': 2,
#  'kick': 2,
#  'off': 2,
#  'euro2004': 1,
#  'kept': 2,
#  'date': 2,
#  'results': 2,
#  'daily': 2,
#  'removed': 2,
#  '83222': 1,
#  'sorry': 2,
#  'unsubscribe': 1,
#  'yet': 2,
#  'package': 2,
#  'term': 2,
#  '54': 1,
#  'weeks': 2,
#  'pls': 2,
#  'resubmit': 1,
#  'request': 2,
#  'expiry': 1,
#  'pass': 2,
#  '69669': 1,
#  'collect': 2,
#  'polyphonic': 1,
#  'ringtones': 1,
#  'normal': 2,
#  'gprs': 1,
#  'charges': 2,
#  'enjoy': 2,
#  'talk': 2,
#  'friends': 2,
#  'fall': 2,
#  'love': 2,
#  'worlds': 2,
#  'discreet': 1,
#  'vip': 1,
#  '83110': 1,
#  'meet': 2,
#  'cash-balance': 1,
#  'currently': 2,
#  'maximize': 1,
#  'cash-in': 1,
#  'hmv1': 1,
#  '150p/msg': 1,
#  'congrats': 2,
#  '3g': 2,
#  'videophones': 1,
#  'yours': 2,
#  '09063458130': 1,
#  'videochat': 1,
#  'wid': 2,
#  'mates': 2,
#  'java': 1,
#  'dload': 1,
#  'polyph': 1,
#  'music': 2,
#  'noline': 1,
#  'rentl': 1,
#  'bx420': 1,
#  'ip4': 1,
#  '5we': 1,
#  'dorothy': 1,
#  'kiefer': 1,
#  'bank': 2,
#  'granite': 1,
#  'issues': 2,
#  'strong-buy': 1,
#  'explosive': 1,
#  'pick': 2,
#  'members': 1,
#  'up': 2,
#  'over': 2,
#  '300': 1,
#  '%': 2,
#  'nasdaq': 1,
#  'symbol': 2,
#  'cdgt': 1,
#  'that': 2,
#  '$': 2,
#  '5': 2,
#  '00': 1,
#  'hi': 2,
#  'chloe': 1,
#  'smashed': 2,
#  'saturday': 2,
#  'night': 2,
#  'how': 2,
#  'missing': 2,
#  'me': 2,
#  'visionsms': 1,
#  '150p/text': 1,
#  'pleased': 2,
#  'advise': 1,
#  'following': 2,
#  'recent': 1,
#  'review': 2,
#  '£1500': 1,
#  '09066364589': 1,
#  'twinks': 1,
#  'bears': 1,
#  'scallies': 1,
#  'skins': 1,
#  'jocks': 1,
#  'calling': 2,
#  'do': 2,
#  "n't": 2,
#  'miss': 2,
#  'fun': 2,
#  '08712466669': 1,
#  '10p/min': 1,
#  'update_now': 1,
#  'xmas': 2,
#  'motorola': 2,
#  'sonyericsson': 1,
#  'bluetooth': 1,
#  '1000': 1,
#  'call2optout/f4q=': 1,
#  'tddnewsletter': 1,
#  'emc1': 1,
#  'thedailydraw': 1,
#  'helen': 2,
#  'dozens': 1,
#  'prizeswith': 1,
#  '8007': 1,
#  'no1': 1,
#  'getzed': 1,
#  'pobox': 1,
#  '36504': 1,
#  'w4': 1,
#  '5wq': 1,
#  'norm': 2,
#  '150p/tone': 1,
#  'starting': 2,
#  '87066': 1,
#  'tscs': 1,
#  'idew': 1,
#  'skillgame': 1,
#  '1winaweek': 1,
#  'age16': 1,
#  '150ppermesssubscription': 1,
#  'video': 2,
#  'movie': 2,
#  '89105': 1,
#  'its': 2,
#  'films': 2,
#  'ordered': 2,
#  'yrs': 2,
#  '09094100151': 1,
#  'calls': 2,
#  'cast': 1,
#  'vary': 1,
#  'provided': 1,
#  'aom': 1,
#  'gbp5/month': 1,
#  'box61': 1,
#  'm60': 1,
#  '1er': 1,
#  'ages': 2,
#  'okmail': 1,
#  'dave': 2,
#  'notice': 2,
#  '#': 2,
#  '5000': 1,
#  '09061743806': 1,
#  'tcs': 1,
#  'box326': 1,
#  'cw25wx': 1,
#  'eg': 1,
#  'real1': 1,
#  'pushbutton': 1,
#  'dontcha': 1,
#  'babygoodbye': 1,
#  'golddigger': 1,
#  'webeburnin': 1,
#  '6': 2,
#  'will': 2,
#  'dream': 2,
#  'partner': 2,
#  'soon': 2,
#  'career': 2,
#  'flyng': 1,
#  'start': 2,
#  'horo': 1,
#  'followed': 2,
#  'star': 1,
#  'sign': 2,
#  'e': 2,
#  'g': 2,
#  'aries': 1,
#  'darling': 2,
#  'today': 2,
#  'would': 2,
#  'dont': 2,
#  'look': 2,
#  '09061213237': 1,
#  '£5000': 1,
#  '177': 1,
#  'm227xy': 1,
#  'costa': 1,
#  'del': 2,
#  'sol': 1,
#  '09050090044': 1,
#  'toclaim': 1,
#  'tc': 2,
#  'pobox334': 1,
#  'stockport': 1,
#  'sk38xh': 1,
#  'cost£1': 1,
#  '50/pm': 1,
#  'max10mins': 1,
#  'fantasy': 1,
#  'football': 2,
#  'back': 2,
#  'tv': 2,
#  'sky': 1,
#  'gamestar': 1,
#  'active': 1,
#  '£250k': 1,
#  'team': 2,
#  'scoring': 1,
#  'starts': 2,
#  'register': 2,
#  'opt': 1,
#  'out': 2,
#  '88088': 1,
#  '09061790121': 1,
#  'land': 1,
#  '3030': 1,
#  '+123': 1,
#  'congratulations': 2,
#  '£1450': 1,
#  '09050002311': 1,
#  'b4280703': 1,
#  'cs/stop': 1,
#  'sms': 2,
#  '08718727868': 1,
#  'check': 2,
#  'choose': 2,
#  'videos': 1,
#  'shsex': 1,
#  'netun': 1,
#  'fgkslpopw': 1,
#  'fgkslpo': 1,
#  'handset': 1,
#  '750': 1,
#  'anytime': 2,
#  'half': 2,
#  'price': 2,
#  'rental': 1,
#  'tomorrow': 2,
#  'stay': 2,
#  '250': 1,
#  'british': 1,
#  'hotels': 1,
#  'nothing': 2,
#  '£350': 1,
#  'dial': 2,
#  '08712300220': 1,
#  'national': 1,
#  'bx526': 1,
#  'sw73ss': 1,
#  'official': 2,
#  'england': 2,
#  'flag': 1,
#  'yer': 1,
#  'tonights': 1,
#  'game': 2,
#  '84199': 1,
#  'optout': 1,
#  'eng': 2,
#  'box39822': 1,
#  'w111wx': 1,
#  'subscribed': 1,
#  'content': 1,
#  '£3': 1,
#  '82324': 1,
#  'helpline': 1,
#  '08706091795': 1,
#  '2004': 1,
#  '07xxxxxxxxx': 1,
#  '786': 1,
#  'unredeemed': 1,
#  '08719181259': 1,
#  'xxxxx': 2,
#  '26': 1,
#  '03': 1,
#  '05': 1,
#  'call2optout/hf8': 1,
#  'a': 2,
#  'picture': 2,
#  'also': 2,
#  '//alto18': 1,
#  'uk/wave/wave': 1,
#  'asp': 1,
#  'o=44345': 1,
#  'summers': 1,
#  'finally': 2,
#  'singles': 1,
#  'yr': 2,
#  'area': 2,
#  'matched': 1,
#  'summer': 2,
#  'help08714742804': 1,
#  'realize': 2,
#  '40': 1,
#  'years': 2,
#  "'ll": 2,
#  'thousands': 2,
#  'old': 2,
#  'running': 2,
#  'around': 2,
#  'tattoos': 1,
#  'recently': 2,
#  'unable': 2,
#  'so': 2,
#  '07090298926': 1,
#  're-schedule': 1,
#  'ref:9307622': 1,
#  'information': 2,
#  'o2': 1,
#  'lucky': 2,
#  'why': 2,
#  'log': 2,
#  'onto': 1,
#  '//www': 1,
#  'urawinner': 1,
#  'there': 2,
#  'fantastic': 2,
#  'surprise': 2,
#  'representative': 1,
#  'mila': 1,
#  'age23': 1,
#  'blonde': 1,
#  'guys': 2,
#  'mtalk': 1,
#  '69866': 1,
#  '30pp/txt': 1,
#  '5free': 1,
#  'increments': 1,
#  'help08718728876': 1,
#  'burger': 2,
#  'king': 2,
#  'footy': 1,
#  'stadium': 1,
#  'sept': 1,
#  'large': 1,
#  'super': 2,
#  'coca-cola': 1,
#  'walk': 2,
#  'gr8': 2,
#  'all': 2,
#  'mobs': 1,
#  '2u': 2,
#  'rply': 2,
#  'title': 2,
#  'breathe1': 1,
#  'titles': 1,
#  'crazyin': 1,
#  'sleepingwith': 1,
#  'finest': 1,
#  'ymca': 1,
#  'pobox365o4w45wq': 1,
#  '300p': 1,
#  '07742676969': 1,
#  '08719180248': 1,
#  '45239': 1,
#  'must': 2,
#  '89545': 1,
#  '4-tc': 1,
#  'biz': 1,
#  '2optout': 1,
#  '087187262701': 1,
#  '50gbp/mtmsg18': 1,
#  'txtauction': 1,
#  'time': 2,
#  'pound': 2,
#  '08712101358': 1,
#  '10p': 1,
#  'bt-national-rate': 1,
#  'funk': 1,
#  'tones2u': 1,
#  'original': 2,
#  'n': 2,
#  '3gbp': 1,
#  'operator': 1,
#  'rates': 2,
#  'ou': 1,
#  '40gb': 1,
#  'ipod': 1,
#  'mp3': 2,
#  '83355': 1,
#  'ibhltd': 1,
#  'ldnw15h': 1,
#  '150p/mtmsgrcvd18': 1,
#  'promotion': 1,
#  '8714714': 1,
#  'city': 2,
#  'break': 2,
#  '£200': 1,
#  'shopping': 2,
#  'spree': 1,
#  'store': 2,
#  '88039': 1,
#  'skilgme': 1,
#  'tscs087147403231winawk': 1,
#  '50perwksub': 1,
#  '078498': 1,
#  '7': 2,
#  '08719180219': 1,
#  '06': 1,
#  '8077': 1,
#  'w45wq': 1,
#  'norm150p/tone': 1,
#  'rayman': 1,
#  'golf': 1,
#  'arcade': 1,
#  'settings': 2,
#  'post': 2,
#  'save': 2,
#  'activ8': 1,
#  'press': 2,
#  '0': 1,
#  'key': 2,
#  'termsapply': 1,
#  'reminder': 2,
#  'downloaded': 2,
#  'already': 2,
#  'paid': 2,
#  'goto': 2,
#  ...}

# %%
ham
# Out:
# {'you': 376,
#  'still': 137,
#  'coming': 46,
#  'tonight': 53,
#  '``': 203,
#  'hey': 94,
#  'babe': 65,
#  'far': 14,
#  '2': 278,
#  'spun-out': 1,
#  'spk': 3,
#  'at': 42,
#  'da': 130,
#  'mo': 9,
#  'dead': 8,
#  'wrld': 1,
#  'been': 10,
#  'sleeping': 17,
#  'on': 35,
#  'sofa': 7,
#  'all': 50,
#  'day': 178,
#  'had': 11,
#  'a': 79,
#  'cool': 38,
#  'nytho': 1,
#  'tx': 1,
#  '4': 170,
#  'fonin': 1,
#  'hon': 3,
#  'call': 217,
#  '2mwen': 1,
#  'im': 73,
#  'bk': 2,
#  'frmcloud': 1,
#  '9': 27,
#  'j': 6,
#  'x': 39,
#  "''": 99,
#  'ya': 53,
#  'even': 54,
#  'cookies': 2,
#  'jelly': 1,
#  'sorry': 138,
#  'i': 1989,
#  "'ve": 70,
#  'gone': 12,
#  'place': 49,
#  'll': 31,
#  'tomorrow': 71,
#  'really': 80,
#  'when': 57,
#  'going': 151,
#  'ride': 5,
#  'bike': 1,
#  'daddy': 6,
#  'shu': 2,
#  'looking': 18,
#  'u': 913,
#  'wan': 74,
#  'tell': 105,
#  "'re": 37,
#  'singapore': 1,
#  'wat': 95,
#  'do': 167,
#  "n't": 105,
#  'think': 113,
#  'about': 16,
#  'what': 126,
#  'have': 86,
#  'got': 224,
#  'how': 170,
#  'use': 37,
#  'it': 251,
#  'that': 149,
#  'good': 212,
#  'ni8': 12,
#  'the': 85,
#  'lay': 1,
#  'man': 38,
#  'just': 93,
#  'let': 68,
#  'know': 212,
#  'missed': 22,
#  'thought': 40,
#  'off': 14,
#  'great': 96,
#  'and': 106,
#  'send': 116,
#  'bimbo': 1,
#  'ugo': 1,
#  "'s": 346,
#  'numbers': 4,
#  'ill': 41,
#  'appreciate': 7,
#  'safe': 9,
#  'thank': 26,
#  'generally': 3,
#  'date': 11,
#  'brothas': 3,
#  'leave': 51,
#  'k': 127,
#  'wen': 23,
#  'ur': 213,
#  'free': 54,
#  'come': 207,
#  'home': 147,
#  'also': 65,
#  'tel': 13,
#  'vikky': 5,
#  'hav': 22,
#  'sent': 54,
#  'mail': 24,
#  'better': 42,
#  'evening': 23,
#  'il': 9,
#  'today': 122,
#  'aftr': 5,
#  '6pm': 2,
#  ':': 505,
#  '-': 151,
#  ')': 394,
#  'yup': 40,
#  'leaving': 19,
#  'right': 84,
#  'now': 160,
#  'back': 117,
#  'soon': 51,
#  'doing': 18,
#  'nothing': 32,
#  'dinner': 35,
#  'w': 14,
#  'us': 56,
#  'convey': 9,
#  'regards': 5,
#  'detail': 1,
#  'want': 148,
#  'transfer': 3,
#  'acc': 4,
#  'enough': 26,
#  'yeah': 77,
#  'open': 16,
#  'chat': 13,
#  'click': 2,
#  'friend': 37,
#  'lists': 1,
#  'then': 89,
#  'make': 77,
#  'list': 6,
#  'easy': 16,
#  'pie': 4,
#  'gon': 53,
#  'na': 86,
#  'miss': 66,
#  'so': 146,
#  'much': 96,
#  'congrats': 9,
#  'wanted': 25,
#  'score': 3,
#  'cos': 71,
#  'might': 33,
#  'relax': 6,
#  'but': 151,
#  'motivating': 1,
#  'thanks': 55,
#  'sharing': 2,
#  'meet': 68,
#  'lunch': 41,
#  'la': 7,
#  'me': 225,
#  'sef': 1,
#  'dey': 7,
#  'laugh': 9,
#  'meanwhile': 4,
#  'darling': 3,
#  'anjie': 1,
#  'oh': 104,
#  'charge': 9,
#  'camera': 3,
#  'hope': 97,
#  'derp': 1,
#  'which': 14,
#  'worse': 6,
#  'dude': 21,
#  'always': 56,
#  'wants': 18,
#  'party': 13,
#  'files': 4,
#  'complaint': 2,
#  'three': 4,
#  'drug': 4,
#  'abusers': 1,
#  'lives': 3,
#  'no': 173,
#  'movies': 6,
#  'laptop': 11,
#  'some': 5,
#  'friends': 45,
#  'drive': 18,
#  'em': 9,
#  'someplace': 1,
#  'probably': 30,
#  'take': 112,
#  'dunno': 31,
#  'ask': 81,
#  'yes': 75,
#  'princess': 29,
#  'catch': 9,
#  'big': 30,
#  'strong': 4,
#  'hands': 5,
#  'dear': 95,
#  'shall': 31,
#  'tonite': 10,
#  'busy': 18,
#  'street': 8,
#  'update': 4,
#  'things': 45,
#  'ok': 256,
#  'varunnathu': 1,
#  'edukkukayee': 1,
#  'raksha': 1,
#  'ollu': 1,
#  'one': 151,
#  'real': 23,
#  'sense': 6,
#  '(': 61,
#  'hear': 26,
#  'promise': 8,
#  'care': 60,
#  'run': 17,
#  'please': 70,
#  'pics': 6,
#  'get': 274,
#  'chance': 12,
#  'ttyl': 5,
#  '*': 171,
#  'deep': 9,
#  'sigh': 2,
#  'surprised': 3,
#  'net': 7,
#  'cafe': 5,
#  'yet': 44,
#  'finished': 17,
#  'work': 92,
#  'something': 62,
#  'trip': 16,
#  'dont': 122,
#  'panic': 2,
#  'surrender': 1,
#  'has': 5,
#  'pattern': 2,
#  'recently': 5,
#  'crap': 2,
#  'weekends': 3,
#  'was': 31,
#  'gr8': 10,
#  'see': 118,
#  'message': 56,
#  'r': 119,
#  'school': 23,
#  'plans': 11,
#  'uncle': 10,
#  'keep': 53,
#  'touch': 15,
#  'workin': 8,
#  'overtime': 1,
#  'nigpun': 1,
#  'bognor': 1,
#  'is': 86,
#  'should': 16,
#  'splendid': 1,
#  'time': 183,
#  'year': 37,
#  'makes': 22,
#  'btw': 5,
#  'carlos': 15,
#  'difficult': 11,
#  'guys': 29,
#  'smoke': 13,
#  'go': 228,
#  'pick': 61,
#  'second': 15,
#  'batch': 2,
#  'gas': 11,
#  "'hex": 1,
#  "'": 30,
#  'talk': 36,
#  'of': 23,
#  'explain': 4,
#  'happen': 15,
#  'why': 30,
#  'silent': 8,
#  'tensed': 1,
#  ';': 661,
#  'well': 105,
#  'c': 55,
#  'later': 121,
#  'konw': 1,
#  'waht': 1,
#  'rael': 1,
#  'friendship': 15,
#  'gving': 1,
#  'yuo': 2,
#  'exmpel': 1,
#  'jsut': 1,
#  'ese': 2,
#  'tihs': 2,
#  'msg': 50,
#  'evrey': 1,
#  'splleing': 1,
#  'wrnog': 1,
#  'bt': 19,
#  'sitll': 1,
#  'raed': 1,
#  'wihtuot': 1,
#  'ayn': 1,
#  'mitsake': 1,
#  'goodnight': 8,
#  '&': 653,
#  'amp': 77,
#  'nice': 54,
#  'sleep': 48,
#  'sweet': 34,
#  'dreams': 19,
#  'frnd': 10,
#  'necesity': 1,
#  'life': 73,
#  'imagine': 7,
#  'urself': 9,
#  'witout': 1,
#  'hw': 7,
#  "'d": 19,
#  'feel': 59,
#  'colleg': 1,
#  "'ll": 198,
#  'wth': 1,
#  'cell': 7,
#  'abt': 24,
#  'functions': 1,
#  'thnk': 6,
#  'events': 1,
#  'espe': 1,
#  'cared': 1,
#  'irritated': 1,
#  '4wrd': 1,
#  'dear-loving': 1,
#  'frnds': 13,
#  'wthout': 1,
#  'cant': 57,
#  'live': 17,
#  'jst': 4,
#  'takecare': 1,
#  'goodmorning': 15,
#  'unless': 7,
#  'situation': 9,
#  'gurl': 1,
#  'would': 69,
#  'appropriate': 1,
#  'lem': 7,
#  'weather': 6,
#  'cali': 2,
#  'complexities': 1,
#  'need': 139,
#  'car': 36,
#  'move': 11,
#  'freely': 1,
#  'taxes': 1,
#  'outrageous': 1,
#  'sad': 19,
#  'part': 18,
#  'missing': 26,
#  'today-sunday': 3,
#  'sunday': 11,
#  'holiday': 15,
#  'aft': 16,
#  'finish': 38,
#  'str': 3,
#  'lor': 148,
#  'ard': 21,
#  '3': 49,
#  'smth': 15,
#  'already': 81,
#  'mm': 9,
#  'look': 26,
#  'hugging': 1,
#  'both': 6,
#  '-p': 4,
#  'imma': 7,
#  'cause': 16,
#  'jay': 13,
#  'drugs': 10,
#  'lol': 66,
#  'quality': 4,
#  'aint': 4,
#  'bad': 27,
#  'complaining': 1,
#  "'m": 356,
#  'freezing': 3,
#  'craving': 1,
#  'ice': 8,
#  'fml': 1,
#  'physics': 1,
#  'a-': 1,
#  'never': 40,
#  'this': 73,
#  'short': 8,
#  'on-edge': 1,
#  'late': 56,
#  'taking': 16,
#  'half': 23,
#  'bec': 2,
#  'or': 43,
#  'maybe': 28,
#  'fat': 6,
#  'fingers': 8,
#  'press': 9,
#  'buttons': 1,
#  'al': 7,
#  'moan': 5,
#  'n': 130,
#  'e': 71,
#  'thin': 1,
#  'goes': 23,
#  'wrong': 14,
#  'fault': 8,
#  'de': 22,
#  'arguments': 1,
#  'fed': 1,
#  'himso': 1,
#  'bother': 6,
#  '2go': 3,
#  'thanx': 30,
#  'xx': 13,
#  'says': 26,
#  'double-faggot': 1,
#  'its': 92,
#  'here': 41,
#  'job': 42,
#  'ta': 15,
#  'earn': 2,
#  'there': 103,
#  'naughty': 6,
#  'little': 24,
#  "'its": 1,
#  'flirt': 3,
#  'rather': 7,
#  'loving': 14,
#  'someone': 42,
#  'gettin': 8,
#  'hurt': 22,
#  'gud': 58,
#  'nyt': 10,
#  'night': 100,
#  'sleepwell': 2,
#  'done': 39,
#  'internet': 6,
#  'connection': 4,
#  'v': 41,
#  'slow': 9,
#  'can': 98,
#  '‘': 32,
#  't': 17,
#  'will': 49,
#  'try': 44,
#  'first': 43,
#  'thing': 52,
#  'tomo': 19,
#  'haha': 49,
#  'awesome': 16,
#  'doin': 9,
#  'somebody': 6,
#  'andros': 2,
#  'steal': 1,
#  'hi': 109,
#  'saw': 23,
#  'we': 126,
#  'happy': 99,
#  'where': 56,
#  'battery': 7,
#  'low': 2,
#  'bet': 4,
#  'chasing': 2,
#  'asked': 21,
#  'anand': 1,
#  'number': 61,
#  'answering': 4,
#  'ca': 57,
#  'reboot': 2,
#  'ym': 4,
#  'photo': 4,
#  'pls': 113,
#  'speak': 21,
#  'customer': 7,
#  'machan': 4,
#  'hoping': 10,
#  'my': 111,
#  'rent': 9,
#  'due': 4,
#  'reserves': 1,
#  'completely': 8,
#  'loan': 5,
#  'could': 48,
#  'her': 27,
#  'balance': 4,
#  'lt': 277,
#  '#': 248,
#  'gt': 279,
#  'way': 94,
#  'till': 18,
#  'mid': 5,
#  'march': 12,
#  'pay': 29,
#  'wait': 60,
#  'chikku': 17,
#  'mins': 11,
#  'course': 14,
#  '2yrs': 1,
#  'messages': 12,
#  'messenger': 3,
#  'lik': 4,
#  'sending': 9,
#  'yo': 35,
#  'parents': 14,
#  'cash': 11,
#  'news': 9,
#  'picked': 4,
#  'downstem': 1,
#  'decimal': 21,
#  'common': 3,
#  'buy': 55,
#  'china': 3,
#  'asia': 1,
#  'find': 48,
#  'less': 10,
#  'expensive': 6,
#  'holla': 7,
#  'whatsup': 2,
#  'midnight': 4,
#  'earliest': 1,
#  'jus': 34,
#  'true': 24,
#  'missin': 3,
#  'him': 19,
#  'anything': 65,
#  'guilty': 3,
#  'bcaz': 1,
#  'mobile': 14,
#  'problem': 35,
#  'listen': 11,
#  'voice': 10,
#  'calls': 15,
#  'guild': 1,
#  'bristol': 2,
#  'road': 8,
#  'somewhere': 10,
#  'weekend': 23,
#  'our': 13,
#  'flight': 2,
#  'week': 60,
#  'afternoon': 25,
#  'any': 22,
#  'prospects': 3,
#  'love': 176,
#  'sighs': 5,
#  'repeat': 1,
#  'instructions': 1,
#  'again': 36,
#  'name': 35,
#  'house': 28,
#  'your': 41,
#  'account': 21,
#  'refilled': 2,
#  'successfully': 3,
#  'inr': 2,
#  'keralacircle': 2,
#  'prepaid': 2,
#  'rs': 11,
#  'transaction': 5,
#  'id': 18,
#  'kr': 2,
#  'cancel': 3,
#  'cheyyamo': 1,
#  'money': 51,
#  'said': 81,
#  'birthday': 30,
#  'came': 23,
#  'hostel': 5,
#  'plz': 21,
#  'class': 38,
#  'hrishi': 2,
#  'ultimately': 1,
#  'tor': 1,
#  'motive': 1,
#  'tui': 1,
#  'achieve': 1,
#  'korli': 1,
#  'for': 25,
#  'fear': 3,
#  'fainting': 1,
#  'housework': 1,
#  'did': 60,
#  'quick': 7,
#  'cuppa': 1,
#  'story': 17,
#  'last': 56,
#  "b'day": 9,
#  'wife': 22,
#  "did'nt": 4,
#  'wish': 44,
#  'forgot': 28,
#  'kids': 9,
#  'went': 51,
#  'colleagues': 6,
#  'getting': 42,
#  'tickets': 5,
#  'walsall': 1,
#  'tue': 1,
#  '6': 30,
#  'th': 10,
#  'mate': 13,
#  'sat': 27,
#  'treat': 14,
#  'txt': 11,
#  'bak': 8,
#  'terry': 1,
#  'hmm': 13,
#  'cuddle': 3,
#  'hold': 12,
#  'arms': 4,
#  'too': 36,
#  'mark': 8,
#  'forever': 9,
#  'prescription': 2,
#  'pain': 25,
#  'unfortunately': 2,
#  'found': 14,
#  'sister': 17,
#  'airport': 4,
#  'bathe': 9,
#  'liao': 32,
#  'dare': 3,
#  'luck': 6,
#  'sorting': 3,
#  'jesus': 4,
#  'armand': 6,
#  'trying': 24,
#  'everybody': 5,
#  'wiskey': 1,
#  'brandy': 1,
#  'rum': 1,
#  'gin': 1,
#  'beer': 3,
#  'vodka': 1,
#  'scotch': 1,
#  'shampain': 1,
#  'wine': 10,
#  'kudi': 1,
#  'yarasu': 1,
#  'dhina': 1,
#  'vaazhthukkal': 1,
#  'cme': 2,
#  'hos': 1,
#  '2morow': 2,
#  'after': 15,
#  'wil': 18,
#  'she': 63,
#  'didnt': 30,
#  'say': 82,
#  'am': 27,
#  'surfing': 4,
#  'online': 22,
#  'store': 3,
#  'offers': 1,
#  'point': 12,
#  'figure': 9,
#  'horrible': 5,
#  'eat': 33,
#  'macs': 1,
#  'rite': 15,
#  'long': 36,
#  'reply': 40,
#  'thk': 46,
#  'toot': 2,
#  'b4': 6,
#  'b': 51,
#  'prepared': 1,
#  'guess': 30,
#  'set': 16,
#  'movie': 16,
#  'theatre': 6,
#  'watch': 32,
#  'unlimited': 2,
#  'once': 11,
#  'wisdom': 3,
#  'teeth': 4,
#  'hidden': 1,
#  'inside': 8,
#  'mayb': 12,
#  'remove': 6,
#  'putting': 5,
#  'ready': 34,
#  'bath': 10,
#  'next': 43,
#  'min': 24,
#  'brainy': 1,
#  'aah': 3,
#  'lush': 2,
#  'lots': 12,
#  'tea': 5,
#  'soup': 3,
#  'kind': 16,
#  'fumbling': 1,
#  '7': 28,
#  'wonders': 2,
#  'world': 32,
#  '7th': 2,
#  '6th': 2,
#  'style': 4,
#  '5th': 2,
#  'smile': 38,
#  '4th': 4,
#  'personality': 2,
#  '3rd': 3,
#  'nature': 4,
#  '2nd': 8,
#  'sms': 15,
#  '1st': 8,
#  'lovely': 12,
#  'morning': 70,
#  'those': 5,
#  'exact': 4,
#  'intentions': 1,
#  'project': 12,
#  'centre': 5,
#  'if': 115,
#  'ring': 15,
#  'comes': 17,
#  'costumes': 1,
#  'gift': 6,
#  'future': 4,
#  'yowifes': 1,
#  'hint': 3,
#  'yay': 5,
#  'told': 50,
#  '5': 39,
#  'girls': 11,
#  'either': 12,
#  'intro': 5,
#  'covers': 2,
#  'energy': 7,
#  'trends': 1,
#  'pros': 1,
#  'cons': 1,
#  'brief': 2,
#  'description': 1,
#  'nuclear': 1,
#  'fusion': 1,
#  'oso': 19,
#  'history': 2,
#  'iter': 1,
#  'jet': 1,
#  'pages': 4,
#  'are': 83,
#  'willing': 5,
#  'aptitude': 1,
#  'engagement': 1,
#  'fixd': 1,
#  'month': 28,
#  'shocking': 2,
#  'njan': 1,
#  'vilikkam': 1,
#  'ws': 3,
#  'sudn': 1,
#  'normally': 3,
#  'drink': 17,
#  'water': 10,
#  'daily': 2,
#  'srsly': 1,
#  'yi': 1,
#  'tho': 16,
#  'seeking': 1,
#  'lady': 6,
#  'freak': 3,
#  'sheets': 3,
#  'sura': 5,
#  'sun': 15,
#  'tv': 22,
#  'as': 29,
#  'usual': 10,
#  'iam': 9,
#  'fine': 49,
#  'cost': 9,
#  'hire': 1,
#  'hitman': 1,
#  'wake': 25,
#  'god': 43,
#  'limit': 1,
#  'grace': 2,
#  'measure': 1,
#  'power': 8,
#  'boundaries': 1,
#  'may': 42,
#  'endless': 1,
#  'blessings': 3,
#  'pa': 27,
#  'srs': 1,
#  'model': 7,
#  'two': 28,
#  'letters': 4,
#  'copy': 8,
#  'wrkin': 1,
#  'check': 32,
#  'wid': 11,
#  'corect': 1,
#  'speling': 1,
#  'sarcasm': 2,
#  'lab': 3,
#  'wot': 25,
#  'wed': 4,
#  'nite': 18,
#  'til': 19,
#  'congratulations': 1,
#  'ore': 1,
#  'owo': 1,
#  'wa': 3,
#  'enjoy': 27,
#  'many': 52,
#  'moments': 2,
#  'fro': 1,
#  'wherever': 5,
#  'gym': 12,
#  'aight': 28,
#  'chillin': 3,
#  'room': 30,
#  'text': 61,
#  'times': 23,
#  'lose': 19,
#  'best': 36,
#  'ones': 6,
#  'bcoz': 12,
#  'pizza': 6,
#  'o': 10,
#  'played': 2,
#  'smash': 1,
#  'bros': 3,
#  'religiously': 1,
#  'mu': 14,
#  'like': 215,
#  'seconds': 3,
#  'pandy': 2,
#  'joined': 6,
#  '4w': 1,
#  'technologies': 1,
#  'he': 100,
#  'fighting': 5,
#  'win': 11,
#  'fightng': 3,
#  'some1': 5,
#  'close': 13,
#  'dificult': 3,
#  'dnt': 13,
#  'worry': 19,
#  'pieces': 3,
#  'cloth': 1,
#  'pack': 4,
#  'tablets': 3,
#  'smsing': 1,
#  'xy': 9,
#  'neva': 16,
#  'person': 39,
#  'sort': 9,
#  'bring': 24,
#  'along': 3,
#  'meeting': 38,
#  'kidding': 2,
#  'papa': 1,
#  'needs': 15,
#  'host-based': 1,
#  'idps': 1,
#  'linux': 1,
#  'systems': 1,
#  'new': 61,
#  '1': 55,
#  'noe': 18,
#  'tmr': 25,
#  's': 38,
#  'nervous': 2,
#  'thinkin': 9,
#  'malaria': 7,
#  'children': 5,
#  'handle': 4,
#  'gastroenteritis': 2,
#  'takes': 11,
#  'replace': 2,
#  'loss': 4,
#  'temp': 3,
#  'reduce': 2,
#  'give': 86,
#  'meds': 4,
#  'vomit': 5,
#  'self': 6,
#  'limiting': 2,
#  'illness': 2,
#  'means': 24,
#  'days': 31,
#  'stop': 36,
#  'threats': 1,
#  'sales': 1,
#  'executive': 3,
#  'shifad': 1,
#  'raised': 1,
#  'official': 1,
#  'okay': 27,
#  'wah': 4,
#  'def': 2,
#  'wont': 30,
#  'terms': 2,
#  'conditions': 1,
#  'don': 15,
#  'aunt': 2,
#  'nike': 1,
#  'ow': 1,
#  'paid': 5,
#  '60': 1,
#  '400thousad': 1,
#  'notice': 4,
#  'shit': 33,
#  'mirror': 1,
#  'youre': 2,
#  'turning': 2,
#  'discussed': 2,
#  'mother': 6,
#  'ah': 31,
#  'beauty': 2,
#  'help': 34,
#  'pimples': 2,
#  'saying': 18,
#  'aathi': 6,
#  'avoid': 1,
#  'missunderstding': 1,
#  'wit': 10,
#  'beloved': 2,
#  'ugh': 12,
#  'apologize': 1,
#  'admit': 2,
#  'eating': 7,
#  'plate': 1,
#  'not': 92,
#  'leftovers': 1,
#  'worried': 10,
#  'must': 22,
#  'body': 5,
#  'repairs': 1,
#  'itself': 6,
#  'quite': 29,
#  'sure': 68,
#  'tests': 2,
#  'guide': 4,
#  'ovulation': 2,
#  'reason': 11,
#  'followin': 1,
#  'up': 59,
#  'bugis': 7,
#  '930': 2,
#  'castor': 2,
#  'another': 31,
#  'gang': 3,
#  'grand': 3,
#  'adventure': 2,
#  'macho': 3,
#  'budget': 6,
#  'bb': 7,
#  'bold': 6,
#  'dollars': 5,
#  'seeing': 13,
#  'brother': 17,
#  'thts': 6,
#  'wright': 1,
#  'fly': 2,
#  'fun': 20,
#  'fact': 9,
#  'although': 2,
#  'eventually': 1,
#  'build': 2,
#  'tolerance': 1,
#  'considering': 3,
#  'smokes': 4,
#  'gets': 11,
#  'fucked': 2,
#  'hits': 1,
#  'rofl': 3,
#  'betta': 1,
#  'invest': 2,
#  'anti': 2,
#  'aging': 1,
#  'products': 1,
#  'coz': 18,
#  'disappeared': 1,
#  'happened': 13,
#  ...}

# %%
len(all_words)
# len(ham)
# len(spam)
# Out:
# 8549

# %%
values = list(ham.values())
count_ham= sum(values)
values = list(spam.values())
count_spam= sum(values)
vocab=len(all_words)
count_spam
# Out:
# 13482

# %% [markdown]
# Prior probAbilities

# %%
prob_spam= len(spam)/(len(ham)+len(spam))
prob_ham= len(ham)/(len(ham)+len(spam))

# %%
cond_prob_spam={}
for item in spam:
    cond_prob_spam[item]=(spam[item]+1)/(count_spam+vocab)
cond_prob_ham={}
for item in ham:
    cond_prob_ham[item]=(ham[item]+1)/(count_spam+vocab)

# %%
cond_prob_spam
# Out:
# {'free': 0.009123507784485497,
#  'message': 0.001361717579773955,
#  'activate': 0.0002269529299623258,
#  '500': 0.0010439834778266988,
#  'text': 0.004856792701193773,
#  'messages': 0.0005446870319095819,
#  'replying': 0.00027234351595479097,
#  'word': 0.0010893740638191639,
#  'for': 0.0014978893377513504,
#  'terms': 0.00031773410194725616,
#  '&': 0.007489446688756752,
#  'conditions': 0.00018156234396986065,
#  'visit': 0.00031773410194725616,
#  'www': 0.003358903363442422,
#  '07781482378': 0.00013617175797739548,
#  'com': 0.0021333575416458625,
#  't-mobile': 0.00018156234396986065,
#  'customer': 0.0021333575416458625,
#  'may': 0.00031773410194725616,
#  'claim': 0.004675230357223912,
#  'camera': 0.0014524987517588852,
#  'phone': 0.0017248422677136762,
#  'upgrade': 0.00018156234396986065,
#  'pay': 9.078117198493032e-05,
#  'go': 0.0011347646498116291,
#  'sim': 0.00013617175797739548,
#  'card': 0.0002269529299623258,
#  'loyalty': 0.0003631246879397213,
#  'call': 0.0140710816576642,
#  '0845': 0.00018156234396986065,
#  '021': 0.00013617175797739548,
#  '3680': 0.00013617175797739548,
#  'offer': 0.0012255458217965594,
#  'ends': 0.0002269529299623258,
#  '28thfeb': 9.078117198493032e-05,
#  't': 0.003041169261495166,
#  'c': 0.0021787481276383277,
#  "'s": 0.002995778675502701,
#  'apply': 0.0012255458217965594,
#  'kit': 9.078117198493032e-05,
#  'strip': 9.078117198493032e-05,
#  '-': 0.002496482229585584,
#  'billed': 0.00013617175797739548,
#  '150p': 0.0009985928918342336,
#  'netcollex': 0.0002269529299623258,
#  'ltd': 0.0006808587898869774,
#  'po': 0.0014071081657664201,
#  'box': 0.0014978893377513504,
#  '1013': 9.078117198493032e-05,
#  'ig11': 9.078117198493032e-05,
#  'oja': 9.078117198493032e-05,
#  'urgent': 0.0026326539875629793,
#  'this': 0.001634061095728746,
#  '2nd': 0.0008624211338568381,
#  'attempt': 0.0009532023058417685,
#  'contact': 0.0023603104716081883,
#  'u': 0.006445463210930053,
#  'your': 0.003358903363442422,
#  '£900': 0.0003631246879397213,
#  'prize': 0.003994371567336934,
#  'yesterday': 0.00018156234396986065,
#  'still': 0.00031773410194725616,
#  'awaiting': 0.0004085152739321865,
#  'collection': 0.0011801552358040941,
#  'to': 0.003631246879397213,
#  'now': 0.005401479733103355,
#  '09061702893': 0.00013617175797739548,
#  'acl03530150pm': 0.00013617175797739548,
#  'germany': 0.00018156234396986065,
#  '1': 0.0018610140256910717,
#  'pence': 0.00018156234396986065,
#  'per': 0.001906404611683537,
#  'minute': 0.0003631246879397213,
#  'fixed': 0.00013617175797739548,
#  'line': 0.0015432799237438154,
#  'via': 0.00018156234396986065,
#  'access': 0.0003631246879397213,
#  'number': 0.0011347646498116291,
#  '0844': 0.00013617175797739548,
#  '861': 0.00013617175797739548,
#  '85': 0.0002269529299623258,
#  'no': 0.0017702328537061414,
#  'prepayment': 0.00013617175797739548,
#  'direct': 0.0004539058599246516,
#  'lastest': 9.078117198493032e-05,
#  'stereophonics': 9.078117198493032e-05,
#  'marley': 9.078117198493032e-05,
#  'dizzee': 9.078117198493032e-05,
#  'racal': 9.078117198493032e-05,
#  'libertines': 9.078117198493032e-05,
#  'the': 0.0011347646498116291,
#  'strokes': 9.078117198493032e-05,
#  'win': 0.0023603104716081883,
#  'nookii': 9.078117198493032e-05,
#  'games': 0.0007262493758794426,
#  'flirt': 0.0002269529299623258,
#  'click': 0.00027234351595479097,
#  'themob': 0.00027234351595479097,
#  'wap': 0.0004539058599246516,
#  'bookmark': 9.078117198493032e-05,
#  '82468': 0.00013617175797739548,
#  'entry': 0.0010893740638191639,
#  '2': 0.0069447596568471695,
#  'wkly': 0.0006354682038945123,
#  'comp': 0.0004539058599246516,
#  'fa': 0.0002269529299623258,
#  'cup': 0.0002269529299623258,
#  'final': 0.0007262493758794426,
#  'tkts': 0.00018156234396986065,
#  '21st': 0.00013617175797739548,
#  '2005': 0.00018156234396986065,
#  '87121': 0.0002269529299623258,
#  'receive': 0.0014524987517588852,
#  'question': 0.00031773410194725616,
#  '(': 0.0020425763696609324,
#  'std': 0.0003631246879397213,
#  'txt': 0.006490853796922518,
#  'rate': 0.0009985928918342336,
#  ')': 0.0024510916435931188,
#  '08452810075over18': 0.00013617175797739548,
#  'dear': 0.0006808587898869774,
#  'subscriber': 0.00018156234396986065,
#  'ur': 0.006036947936997866,
#  'draw': 0.001634061095728746,
#  '4': 0.004947573873178702,
#  '£100': 0.0009985928918342336,
#  'gift': 0.0007716399618719077,
#  'voucher': 0.0005900776179020471,
#  'b': 0.0005900776179020471,
#  'entered': 0.0002269529299623258,
#  'receipt': 0.00013617175797739548,
#  'correct': 0.00018156234396986065,
#  'ans': 0.00018156234396986065,
#  'when': 0.00013617175797739548,
#  'elvis': 9.078117198493032e-05,
#  'presleys': 9.078117198493032e-05,
#  'birthday': 9.078117198493032e-05,
#  'answer': 0.0004085152739321865,
#  '80062': 0.00018156234396986065,
#  'i': 0.0024057010576006535,
#  "'d": 0.00013617175797739548,
#  'like': 0.0005900776179020471,
#  'tell': 0.0006808587898869774,
#  'deepest': 9.078117198493032e-05,
#  'darkest': 9.078117198493032e-05,
#  'fantasies': 0.00031773410194725616,
#  '09094646631': 9.078117198493032e-05,
#  '60p/min': 0.0002269529299623258,
#  'stop': 0.0049021832871862375,
#  'texts': 0.0007716399618719077,
#  '08712460324': 0.0004085152739321865,
#  'nat': 0.00018156234396986065,
#  'moby': 0.0002269529299623258,
#  'pub': 0.00013617175797739548,
#  'quiz': 0.0005446870319095819,
#  'high': 0.00013617175797739548,
#  'street': 0.00013617175797739548,
#  'know': 0.0009078117198493032,
#  'new': 0.002768825745540375,
#  'duchess': 0.00013617175797739548,
#  'cornwall': 0.00013617175797739548,
#  'be': 0.0002269529299623258,
#  'first': 0.00031773410194725616,
#  'name': 0.0006354682038945123,
#  '82277': 0.00031773410194725616,
#  'unsub': 0.0003631246879397213,
#  '£1': 0.001361717579773955,
#  '50': 0.0014071081657664201,
#  '008704050406': 0.00013617175797739548,
#  'sp': 0.00031773410194725616,
#  'arrow': 9.078117198493032e-05,
#  'someonone': 9.078117198493032e-05,
#  'trying': 0.0006808587898869774,
#  'dating': 0.0006354682038945123,
#  'service': 0.0022695292996232582,
#  'find': 0.0009532023058417685,
#  'could': 0.00031773410194725616,
#  'mobile': 0.004992964459171168,
#  'landline': 0.001361717579773955,
#  '09064015307': 9.078117198493032e-05,
#  'box334sk38ch': 0.00013617175797739548,
#  'hello': 0.0002269529299623258,
#  'orange': 0.0012709364077890246,
#  'month': 0.00013617175797739548,
#  'news': 0.0004539058599246516,
#  'sport': 0.0002269529299623258,
#  'plus': 0.00031773410194725616,
#  '10': 0.0004992964459171168,
#  '20': 0.00031773410194725616,
#  'photo': 0.00018156234396986065,
#  'reply': 0.00413054332531433,
#  'yes': 0.0006808587898869774,
#  ':': 0.006672416140892379,
#  'co': 0.0020425763696609324,
#  'uk/ow': 9.078117198493032e-05,
#  'wamma': 9.078117198493032e-05,
#  'get': 0.003404293949434887,
#  'laid': 0.00018156234396986065,
#  'want': 0.0011347646498116291,
#  'real': 0.0005446870319095819,
#  'doggin': 9.078117198493032e-05,
#  'locations': 0.0002269529299623258,
#  'sent': 0.0004085152739321865,
#  'join': 0.0007262493758794426,
#  'uks': 0.00018156234396986065,
#  'largest': 0.00018156234396986065,
#  'dogging': 0.0004539058599246516,
#  'network': 0.0009078117198493032,
#  'dogs': 9.078117198493032e-05,
#  '69696': 0.00013617175797739548,
#  'nyt': 0.00018156234396986065,
#  'ec2a': 0.0002269529299623258,
#  '3lp': 0.00018156234396986065,
#  '50/msg': 0.00013617175797739548,
#  'someone': 0.0004539058599246516,
#  'contacted': 0.0002269529299623258,
#  'fancy': 0.0004085152739321865,
#  'you': 0.005129136217148563,
#  '09111032124': 9.078117198493032e-05,
#  'pobox12n146tf150p': 9.078117198493032e-05,
#  'we': 0.0014978893377513504,
#  'last': 0.0004539058599246516,
#  'weekends': 0.0002269529299623258,
#  'shows': 0.001361717579773955,
#  'guaranteed': 0.0021787481276383277,
#  '09061701939': 9.078117198493032e-05,
#  'code': 0.0012709364077890246,
#  's89': 9.078117198493032e-05,
#  'valid': 0.0010439834778266988,
#  '12hrs': 0.0007262493758794426,
#  'winner': 0.0007262493758794426,
#  'as': 0.0005446870319095819,
#  'valued': 0.0005446870319095819,
#  'selected': 0.0010893740638191639,
#  'receivea': 0.00013617175797739548,
#  'reward': 0.0004539058599246516,
#  '09061701461': 0.00013617175797739548,
#  'kl341': 0.00013617175797739548,
#  '12': 0.0002269529299623258,
#  'hours': 0.0002269529299623258,
#  'only': 0.0013163269937814896,
#  'had': 0.0007716399618719077,
#  '11': 0.00031773410194725616,
#  'months': 0.00018156234396986065,
#  'more': 0.0004992964459171168,
#  'r': 0.0011801552358040941,
#  'entitled': 0.0003631246879397213,
#  'update': 0.000817030547864373,
#  'latest': 0.0015432799237438154,
#  'colour': 0.0007262493758794426,
#  'mobiles': 0.0005446870319095819,
#  '08002986030': 0.00013617175797739548,
#  'unique': 0.00013617175797739548,
#  'user': 0.0004085152739321865,
#  'id': 9.078117198493032e-05,
#  '1172': 9.078117198493032e-05,
#  'removal': 0.00013617175797739548,
#  'send': 0.0029049975035177703,
#  '87239': 0.0002269529299623258,
#  'services': 0.0006808587898869774,
#  '08708034412': 0.00013617175797739548,
#  'tried': 0.0007716399618719077,
#  'response': 9.078117198493032e-05,
#  'nokia': 0.0024510916435931188,
#  'fone': 0.0002269529299623258,
#  'camcorder': 0.0007262493758794426,
#  'hit': 0.0002269529299623258,
#  '08000930705': 0.0007716399618719077,
#  'delivery': 0.0009532023058417685,
#  'gsoh': 9.078117198493032e-05,
#  'good': 0.0005900776179020471,
#  'spam': 9.078117198493032e-05,
#  'ladies': 0.00018156234396986065,
#  'male': 0.00018156234396986065,
#  'gigolo': 9.078117198493032e-05,
#  'uk': 0.0024057010576006535,
#  'fastest': 0.00013617175797739548,
#  'growing': 0.00013617175797739548,
#  'mens': 9.078117198493032e-05,
#  'club': 0.0008624211338568381,
#  'oncall': 9.078117198493032e-05,
#  'mjzgroup': 9.078117198493032e-05,
#  '08714342399': 9.078117198493032e-05,
#  '2stop': 0.00013617175797739548,
#  'msg': 0.0012709364077890246,
#  '@': 0.0010893740638191639,
#  '50rcvd': 9.078117198493032e-05,
#  'hmv': 0.0004992964459171168,
#  'bonus': 0.0009532023058417685,
#  'special': 0.00031773410194725616,
#  'pounds': 0.0007716399618719077,
#  'genuine': 0.00018156234396986065,
#  'vouchers': 0.0009532023058417685,
#  'won': 0.0012709364077890246,
#  'just': 0.001361717579773955,
#  'easy': 0.0005900776179020471,
#  'questions': 0.00031773410194725616,
#  'play': 0.0008624211338568381,
#  '86688': 0.0009078117198493032,
#  'info': 0.0005900776179020471,
#  '100percent-real': 0.00018156234396986065,
#  'ringtone': 0.0012255458217965594,
#  '87131': 0.0002269529299623258,
#  'poly': 0.0007716399618719077,
#  'true': 0.00018156234396986065,
#  'tone': 0.0018156234396986065,
#  'help': 0.0006354682038945123,
#  '2814032': 9.078117198493032e-05,
#  '16': 0.0011801552358040941,
#  '1st': 0.0010893740638191639,
#  'tones': 0.0009985928918342336,
#  '3x£150pw': 9.078117198493032e-05,
#  'e£nd': 9.078117198493032e-05,
#  '09066612661': 0.00013617175797739548,
#  'complementary': 9.078117198493032e-05,
#  '*': 0.004448277427261586,
#  'tenerife': 0.0003631246879397213,
#  'holiday': 0.0014071081657664201,
#  '£10': 0.0004992964459171168,
#  '000': 0.0013163269937814896,
#  'cash': 0.002496482229585584,
#  'await': 0.0008624211338568381,
#  'sae': 0.0009532023058417685,
#  'cs': 0.0017248422677136762,
#  '3': 0.0011347646498116291,
#  'wa14': 9.078117198493032e-05,
#  '2px': 9.078117198493032e-05,
#  '150ppm': 0.0014071081657664201,
#  '18+': 0.000817030547864373,
#  'sender': 9.078117198493032e-05,
#  'hol': 9.078117198493032e-05,
#  'awarded': 0.001634061095728746,
#  'caller': 0.0005446870319095819,
#  '27/6/03': 9.078117198493032e-05,
#  'our': 0.0004085152739321865,
#  '08714714011': 9.078117198493032e-05,
#  'sunshine': 0.0003631246879397213,
#  'q': 0.00018156234396986065,
#  'top': 0.0007262493758794426,
#  'sony': 0.0003631246879397213,
#  'dvd': 0.00027234351595479097,
#  'player': 0.0004992964459171168,
#  'country': 0.00018156234396986065,
#  'liverpool': 0.00013617175797739548,
#  'played': 9.078117198493032e-05,
#  'mid': 9.078117198493032e-05,
#  'week': 0.001997185783668467,
#  'ansr': 0.00018156234396986065,
#  'tyrone': 0.00018156234396986065,
#  '£2000': 0.0009078117198493032,
#  '10/06/03': 9.078117198493032e-05,
#  'reach': 0.00027234351595479097,
#  '09066368753': 9.078117198493032e-05,
#  'asap': 0.00031773410194725616,
#  '97n7qp': 9.078117198493032e-05,
#  'guess': 0.00027234351595479097,
#  'what': 0.0002269529299623258,
#  'somebody': 0.00013617175797739548,
#  'secretly': 0.00013617175797739548,
#  'fancies': 0.00013617175797739548,
#  'wan': 0.0005900776179020471,
#  'na': 0.0004992964459171168,
#  'is': 0.0006808587898869774,
#  'give': 0.00031773410194725616,
#  'us': 0.0004539058599246516,
#  '09065394514': 9.078117198493032e-05,
#  'from': 0.0006354682038945123,
#  'datebox1282essexcm61xn': 0.00013617175797739548,
#  '150p/min': 0.0002269529299623258,
#  '18': 0.0011801552358040941,
#  'xxxmobilemovieclub': 0.00013617175797739548,
#  'use': 0.0004085152739321865,
#  'credit': 0.0004085152739321865,
#  'link': 0.00031773410194725616,
#  'next': 0.0005446870319095819,
#  'here': 0.00018156234396986065,
#  '>': 0.0009985928918342336,
#  'http': 0.000817030547864373,
#  '//wap': 9.078117198493032e-05,
#  'n=qjkgighjjgcbl': 9.078117198493032e-05,
#  'unlimited': 0.0004992964459171168,
#  'hardcore': 0.00013617175797739548,
#  'porn': 0.0002269529299623258,
#  '69200': 9.078117198493032e-05,
#  '24': 0.00013617175797739548,
#  'hrs': 9.078117198493032e-05,
#  'chrgd': 9.078117198493032e-05,
#  '50p': 0.00027234351595479097,
#  'day': 0.0007716399618719077,
#  '2exit': 9.078117198493032e-05,
#  'conacted': 9.078117198493032e-05,
#  '09111030116': 9.078117198493032e-05,
#  'pobox12n146tf15': 9.078117198493032e-05,
#  '7250i': 0.00018156234396986065,
#  'auction': 0.0007262493758794426,
#  'take': 0.0004992964459171168,
#  'part': 0.0004539058599246516,
#  '86021': 0.00027234351595479097,
#  'hg/suite342/2lands': 0.0003631246879397213,
#  'row/w1jhl': 0.00018156234396986065,
#  '16+': 0.0009985928918342336,
#  'secret': 0.0004539058599246516,
#  'admirer': 0.0004539058599246516,
#  'looking': 0.0004539058599246516,
#  'make': 0.0006354682038945123,
#  'u-find': 0.0004085152739321865,
#  'reveal': 0.0004992964459171168,
#  'thinks': 0.0004539058599246516,
#  'special-call': 0.0004085152739321865,
#  '09058094565': 0.00013617175797739548,
#  'weekend': 0.00031773410194725616,
#  '£1000': 0.0014071081657664201,
#  'spanish': 0.00013617175797739548,
#  '09050000332': 9.078117198493032e-05,
#  'rstm': 0.00013617175797739548,
#  'sw7': 0.00013617175797739548,
#  '3ss': 0.00013617175797739548,
#  'december': 0.0002269529299623258,
#  '11mths+': 0.0002269529299623258,
#  '08002986906': 0.00018156234396986065,
#  '£250': 0.0005900776179020471,
#  'weekly': 0.0009532023058417685,
#  'competition': 0.00018156234396986065,
#  '80086': 0.00013617175797739548,
#  'txttowin': 0.00013617175797739548,
#  'sex': 0.0005446870319095819,
#  'sexy': 0.0006808587898869774,
#  'pic': 0.0005446870319095819,
#  'jordan': 0.0002269529299623258,
#  'babe': 0.0004085152739321865,
#  '88600': 0.00018156234396986065,
#  'then': 0.00013617175797739548,
#  'every': 0.0013163269937814896,
#  'wk': 0.0007716399618719077,
#  'celeb': 0.00018156234396986065,
#  'pocketbabe': 0.00018156234396986065,
#  'pics': 0.0005446870319095819,
#  '£3/wk': 0.0002269529299623258,
#  '087016248': 9.078117198493032e-05,
#  "'ve": 0.0004085152739321865,
#  'invited': 0.00027234351595479097,
#  'xchat': 0.00027234351595479097,
#  'chat': 0.001951795197676002,
#  'important': 0.0004992964459171168,
#  'announcement': 0.0002269529299623258,
#  'freephone': 0.00031773410194725616,
#  '0800': 0.0004539058599246516,
#  '542': 0.00013617175797739548,
#  '0825': 9.078117198493032e-05,
#  'tonight': 9.078117198493032e-05,
#  'mob': 0.0009532023058417685,
#  'bt': 0.0002269529299623258,
#  'txting': 0.0003631246879397213,
#  'gravel': 9.078117198493032e-05,
#  '69888': 0.00013617175797739548,
#  'nt': 9.078117198493032e-05,
#  '31p': 9.078117198493032e-05,
#  'asked': 0.0002269529299623258,
#  'shy': 9.078117198493032e-05,
#  '09058091870': 9.078117198493032e-05,
#  'revealed': 0.00018156234396986065,
#  'pobox84': 0.00027234351595479097,
#  'm26': 0.00013617175797739548,
#  '3uz': 0.00013617175797739548,
#  '£500': 0.000817030547864373,
#  'award': 0.0010893740638191639,
#  'unclaimed': 9.078117198493032e-05,
#  '09066368327': 9.078117198493032e-05,
#  'closingdate04/09/02': 9.078117198493032e-05,
#  'claimcode': 9.078117198493032e-05,
#  'm39m51': 9.078117198493032e-05,
#  '50pmmorefrommobile2bremoved-mobypobox734ls27yf': 9.078117198493032e-05,
#  'great': 0.0004992964459171168,
#  'double': 0.000817030547864373,
#  'mins': 0.0015432799237438154,
#  'best': 0.0003631246879397213,
#  'tariffs': 0.00031773410194725616,
#  'and': 0.00013617175797739548,
#  'phones': 0.0005900776179020471,
#  'mobileupd8': 0.0007716399618719077,
#  '08000839402': 0.0007262493758794426,
#  '2stoptxt': 0.00018156234396986065,
#  '2/2': 9.078117198493032e-05,
#  '146tf150p': 9.078117198493032e-05,
#  '5/9/03': 9.078117198493032e-05,
#  'try': 0.0003631246879397213,
#  '09064019788': 9.078117198493032e-05,
#  'box42wr29c': 9.078117198493032e-05,
#  'thanks': 0.0006354682038945123,
#  'order': 0.0005900776179020471,
#  'reference': 0.00018156234396986065,
#  'x49': 0.00013617175797739548,
#  'charged': 0.0004539058599246516,
#  'should': 0.00027234351595479097,
#  'arrive': 0.00027234351595479097,
#  'please': 0.0021333575416458625,
#  '09065989182': 0.00013617175797739548,
#  'loans': 9.078117198493032e-05,
#  'purpose': 0.00018156234396986065,
#  'even': 0.00027234351595479097,
#  'bad': 9.078117198493032e-05,
#  'tenants': 0.00018156234396986065,
#  'welcome': 0.0004085152739321865,
#  'noworriesloans': 9.078117198493032e-05,
#  '08717111821': 9.078117198493032e-05,
#  'private': 0.000817030547864373,
#  '2003': 0.0005900776179020471,
#  'account': 0.000817030547864373,
#  'statement': 0.0007262493758794426,
#  '800': 0.0005446870319095819,
#  'un-redeemed': 0.0005446870319095819,
#  's': 0.0007716399618719077,
#  'm': 0.0005900776179020471,
#  'points': 0.0007262493758794426,
#  '08715203685': 9.078117198493032e-05,
#  'identifier': 0.0007262493758794426,
#  'code:4xx26': 9.078117198493032e-05,
#  'expires': 0.0007716399618719077,
#  '13/10/04': 9.078117198493032e-05,
#  'taking': 9.078117198493032e-05,
#  'survey': 9.078117198493032e-05,
#  'however': 9.078117198493032e-05,
#  'wish': 0.00013617175797739548,
#  'txts': 0.0005900776179020471,
#  '80160': 9.078117198493032e-05,
#  'txt43': 9.078117198493032e-05,
#  '447801259231': 0.00013617175797739548,
#  '09058094597': 0.00013617175797739548,
#  'mths': 0.0002269529299623258,
#  'camera/video': 0.00013617175797739548,
#  'keep': 0.00027234351595479097,
#  'same': 9.078117198493032e-05,
#  'extra': 0.00031773410194725616,
#  'mins/texts': 9.078117198493032e-05,
#  'banneduk': 9.078117198493032e-05,
#  '89555': 0.00018156234396986065,
#  'see': 0.0008624211338568381,
#  'cost': 0.0009985928918342336,
#  'textoperator': 0.00018156234396986065,
#  'g696ga': 0.00013617175797739548,
#  'xxx': 0.0004992964459171168,
#  'call09050000327': 0.00013617175797739548,
#  'vote': 9.078117198493032e-05,
#  'sing': 0.00013617175797739548,
#  'along': 9.078117198493032e-05,
#  'stars': 9.078117198493032e-05,
#  'karaoke': 9.078117198493032e-05,
#  '09090900040': 9.078117198493032e-05,
#  'listen': 0.00013617175797739548,
#  'extreme': 9.078117198493032e-05,
#  'dirty': 9.078117198493032e-05,
#  'live': 0.0013163269937814896,
#  'going': 0.0002269529299623258,
#  'on': 0.0004085152739321865,
#  'in': 0.0004539058599246516,
#  'office': 9.078117198493032e-05,
#  'right': 0.00018156234396986065,
#  'total': 9.078117198493032e-05,
#  'privacy': 9.078117198493032e-05,
#  'one': 0.0004085152739321865,
#  'knows': 9.078117198493032e-05,
#  '[': 0.00018156234396986065,
#  'sic': 9.078117198493032e-05,
#  ']': 0.00018156234396986065,
#  'listening': 9.078117198493032e-05,
#  '60p': 9.078117198493032e-05,
#  'min': 0.0006808587898869774,
#  '24/7mp': 9.078117198493032e-05,
#  '0870753331018+': 9.078117198493032e-05,
#  '22': 9.078117198493032e-05,
#  'days': 0.0005900776179020471,
#  'kick': 0.00018156234396986065,
#  'off': 0.00013617175797739548,
#  'euro2004': 0.0002269529299623258,
#  'kept': 0.00018156234396986065,
#  'date': 0.0004539058599246516,
#  'results': 0.00018156234396986065,
#  'daily': 0.0002269529299623258,
#  'removed': 9.078117198493032e-05,
#  '83222': 0.00018156234396986065,
#  'sorry': 0.00018156234396986065,
#  'unsubscribe': 0.0007716399618719077,
#  'yet': 0.00013617175797739548,
#  'package': 9.078117198493032e-05,
#  'term': 0.00013617175797739548,
#  '54': 9.078117198493032e-05,
#  'weeks': 0.00031773410194725616,
#  'pls': 0.0004539058599246516,
#  'resubmit': 9.078117198493032e-05,
#  'request': 9.078117198493032e-05,
#  'expiry': 9.078117198493032e-05,
#  'pass': 0.00018156234396986065,
#  '69669': 0.00013617175797739548,
#  'collect': 0.0009532023058417685,
#  'polyphonic': 0.00027234351595479097,
#  'ringtones': 0.0004085152739321865,
#  'normal': 9.078117198493032e-05,
#  'gprs': 9.078117198493032e-05,
#  'charges': 9.078117198493032e-05,
#  'enjoy': 0.0004992964459171168,
#  'talk': 0.00018156234396986065,
#  'friends': 0.00027234351595479097,
#  'fall': 9.078117198493032e-05,
#  'love': 0.0004992964459171168,
#  'worlds': 9.078117198493032e-05,
#  'discreet': 0.00013617175797739548,
#  'vip': 0.0002269529299623258,
#  '83110': 9.078117198493032e-05,
#  'meet': 0.00031773410194725616,
#  'cash-balance': 0.0003631246879397213,
#  'currently': 0.0004992964459171168,
#  'maximize': 0.0003631246879397213,
#  'cash-in': 0.0003631246879397213,
#  'hmv1': 9.078117198493032e-05,
#  '150p/msg': 0.0006808587898869774,
#  'congrats': 0.0004085152739321865,
#  '3g': 0.00027234351595479097,
#  'videophones': 0.00027234351595479097,
#  'yours': 0.0004085152739321865,
#  '09063458130': 0.00018156234396986065,
#  'videochat': 0.00027234351595479097,
#  'wid': 0.00027234351595479097,
#  'mates': 0.0005446870319095819,
#  'java': 0.00027234351595479097,
#  'dload': 0.00027234351595479097,
#  'polyph': 0.00018156234396986065,
#  'music': 0.0009532023058417685,
#  'noline': 0.00027234351595479097,
#  'rentl': 0.00027234351595479097,
#  'bx420': 0.0002269529299623258,
#  'ip4': 0.00027234351595479097,
#  '5we': 0.00027234351595479097,
#  'dorothy': 9.078117198493032e-05,
#  'kiefer': 9.078117198493032e-05,
#  'bank': 9.078117198493032e-05,
#  'granite': 9.078117198493032e-05,
#  'issues': 9.078117198493032e-05,
#  'strong-buy': 9.078117198493032e-05,
#  'explosive': 9.078117198493032e-05,
#  'pick': 9.078117198493032e-05,
#  'members': 0.00013617175797739548,
#  'up': 9.078117198493032e-05,
#  'over': 0.0004085152739321865,
#  '300': 0.0002269529299623258,
#  '%': 9.078117198493032e-05,
#  'nasdaq': 9.078117198493032e-05,
#  'symbol': 9.078117198493032e-05,
#  'cdgt': 9.078117198493032e-05,
#  'that': 0.00013617175797739548,
#  '$': 0.00018156234396986065,
#  '5': 0.0004539058599246516,
#  '00': 0.0004085152739321865,
#  'hi': 0.0007262493758794426,
#  'chloe': 9.078117198493032e-05,
#  'smashed': 9.078117198493032e-05,
#  'saturday': 0.0003631246879397213,
#  'night': 0.0002269529299623258,
#  'how': 0.00018156234396986065,
#  'missing': 9.078117198493032e-05,
#  'me': 0.0004992964459171168,
#  'visionsms': 0.00013617175797739548,
#  '150p/text': 9.078117198493032e-05,
#  'pleased': 0.00018156234396986065,
#  'advise': 0.00018156234396986065,
#  'following': 0.00027234351595479097,
#  'recent': 0.00018156234396986065,
#  'review': 0.00018156234396986065,
#  '£1500': 0.00018156234396986065,
#  '09066364589': 0.00013617175797739548,
#  'twinks': 9.078117198493032e-05,
#  'bears': 0.00013617175797739548,
#  'scallies': 9.078117198493032e-05,
#  'skins': 9.078117198493032e-05,
#  'jocks': 9.078117198493032e-05,
#  'calling': 0.0002269529299623258,
#  'do': 0.000817030547864373,
#  "n't": 0.00027234351595479097,
#  'miss': 0.00027234351595479097,
#  'fun': 0.0004085152739321865,
#  '08712466669': 9.078117198493032e-05,
#  '10p/min': 0.0004992964459171168,
#  'update_now': 0.00013617175797739548,
#  'xmas': 0.0006354682038945123,
#  'motorola': 0.0005446870319095819,
#  'sonyericsson': 0.00027234351595479097,
#  'bluetooth': 0.0004539058599246516,
#  '1000': 0.00027234351595479097,
#  'call2optout/f4q=': 9.078117198493032e-05,
#  'tddnewsletter': 9.078117198493032e-05,
#  'emc1': 9.078117198493032e-05,
#  'thedailydraw': 9.078117198493032e-05,
#  'helen': 9.078117198493032e-05,
#  'dozens': 9.078117198493032e-05,
#  'prizeswith': 9.078117198493032e-05,
#  '8007': 0.0007716399618719077,
#  'no1': 0.00031773410194725616,
#  'getzed': 0.0003631246879397213,
#  'pobox': 0.0004992964459171168,
#  '36504': 0.00027234351595479097,
#  'w4': 9.078117198493032e-05,
#  '5wq': 9.078117198493032e-05,
#  'norm': 0.00013617175797739548,
#  '150p/tone': 0.00027234351595479097,
#  'starting': 0.0002269529299623258,
#  '87066': 0.0006354682038945123,
#  'tscs': 0.00018156234396986065,
#  'idew': 0.00013617175797739548,
#  'skillgame': 0.00018156234396986065,
#  '1winaweek': 0.00018156234396986065,
#  'age16': 0.00031773410194725616,
#  '150ppermesssubscription': 0.00018156234396986065,
#  'video': 0.0011801552358040941,
#  'movie': 0.00013617175797739548,
#  '89105': 9.078117198493032e-05,
#  'its': 0.00013617175797739548,
#  'films': 0.00013617175797739548,
#  'ordered': 0.00018156234396986065,
#  'yrs': 0.00018156234396986065,
#  '09094100151': 9.078117198493032e-05,
#  'calls': 0.0004992964459171168,
#  'cast': 9.078117198493032e-05,
#  'vary': 0.00027234351595479097,
#  'provided': 0.00018156234396986065,
#  'aom': 0.00013617175797739548,
#  'gbp5/month': 9.078117198493032e-05,
#  'box61': 9.078117198493032e-05,
#  'm60': 9.078117198493032e-05,
#  '1er': 9.078117198493032e-05,
#  'ages': 9.078117198493032e-05,
#  'okmail': 9.078117198493032e-05,
#  'dave': 0.00013617175797739548,
#  'notice': 0.00018156234396986065,
#  '#': 0.00031773410194725616,
#  '5000': 0.0002269529299623258,
#  '09061743806': 0.00013617175797739548,
#  'tcs': 0.0002269529299623258,
#  'box326': 0.00013617175797739548,
#  'cw25wx': 0.0002269529299623258,
#  'eg': 0.0004539058599246516,
#  'real1': 9.078117198493032e-05,
#  'pushbutton': 9.078117198493032e-05,
#  'dontcha': 9.078117198493032e-05,
#  'babygoodbye': 9.078117198493032e-05,
#  'golddigger': 9.078117198493032e-05,
#  'webeburnin': 9.078117198493032e-05,
#  '6': 0.00027234351595479097,
#  'will': 0.00027234351595479097,
#  'dream': 0.00018156234396986065,
#  'partner': 0.00018156234396986065,
#  'soon': 0.00018156234396986065,
#  'career': 9.078117198493032e-05,
#  'flyng': 9.078117198493032e-05,
#  'start': 0.0003631246879397213,
#  'horo': 0.00013617175797739548,
#  'followed': 0.00018156234396986065,
#  'star': 0.00013617175797739548,
#  'sign': 0.00013617175797739548,
#  'e': 0.00031773410194725616,
#  'g': 0.0004992964459171168,
#  'aries': 9.078117198493032e-05,
#  'darling': 0.00013617175797739548,
#  'today': 0.0009532023058417685,
#  'would': 0.00018156234396986065,
#  'dont': 0.0004539058599246516,
#  'look': 0.00018156234396986065,
#  '09061213237': 0.00013617175797739548,
#  '£5000': 0.0009078117198493032,
#  '177': 0.00013617175797739548,
#  'm227xy': 0.00013617175797739548,
#  'costa': 0.0003631246879397213,
#  'del': 0.0004539058599246516,
#  'sol': 0.0003631246879397213,
#  '09050090044': 0.00031773410194725616,
#  'toclaim': 0.00031773410194725616,
#  'tc': 0.00031773410194725616,
#  'pobox334': 0.00031773410194725616,
#  'stockport': 0.00031773410194725616,
#  'sk38xh': 0.0003631246879397213,
#  'cost£1': 0.00031773410194725616,
#  '50/pm': 0.00031773410194725616,
#  'max10mins': 0.00031773410194725616,
#  'fantasy': 0.00027234351595479097,
#  'football': 0.00013617175797739548,
#  'back': 0.0010439834778266988,
#  'tv': 0.00031773410194725616,
#  'sky': 0.00031773410194725616,
#  'gamestar': 0.00013617175797739548,
#  'active': 0.00013617175797739548,
#  '£250k': 0.00013617175797739548,
#  'team': 0.00018156234396986065,
#  'scoring': 0.00013617175797739548,
#  'starts': 0.0002269529299623258,
#  'register': 0.00013617175797739548,
#  'opt': 0.0005446870319095819,
#  'out': 0.0005446870319095819,
#  '88088': 0.00013617175797739548,
#  '09061790121': 0.00018156234396986065,
#  'land': 0.000817030547864373,
#  '3030': 0.0004085152739321865,
#  '+123': 0.00013617175797739548,
#  'congratulations': 0.0006808587898869774,
#  '£1450': 0.00018156234396986065,
#  '09050002311': 0.00013617175797739548,
#  'b4280703': 0.00013617175797739548,
#  'cs/stop': 0.00018156234396986065,
#  'sms': 0.0013163269937814896,
#  '08718727868': 0.00013617175797739548,
#  'check': 0.0002269529299623258,
#  'choose': 0.0004992964459171168,
#  'videos': 9.078117198493032e-05,
#  'shsex': 9.078117198493032e-05,
#  'netun': 9.078117198493032e-05,
#  'fgkslpopw': 9.078117198493032e-05,
#  'fgkslpo': 9.078117198493032e-05,
#  'handset': 0.00031773410194725616,
#  '750': 0.0007716399618719077,
#  'anytime': 0.0004992964459171168,
#  'half': 0.0005900776179020471,
#  'price': 0.0007716399618719077,
#  'rental': 0.0005446870319095819,
#  'tomorrow': 0.0004539058599246516,
#  'stay': 0.00013617175797739548,
#  '250': 0.0002269529299623258,
#  'british': 0.00013617175797739548,
#  'hotels': 0.00013617175797739548,
#  'nothing': 0.00018156234396986065,
#  '£350': 0.0005446870319095819,
#  'dial': 9.078117198493032e-05,
#  '08712300220': 0.00031773410194725616,
#  'national': 0.0005900776179020471,
#  'bx526': 9.078117198493032e-05,
#  'sw73ss': 0.00013617175797739548,
#  'official': 0.0002269529299623258,
#  'england': 0.0004085152739321865,
#  'flag': 0.0003631246879397213,
#  'yer': 0.00018156234396986065,
#  'tonights': 0.00013617175797739548,
#  'game': 0.0003631246879397213,
#  '84199': 0.00018156234396986065,
#  'optout': 0.00027234351595479097,
#  'eng': 0.00018156234396986065,
#  'box39822': 0.00018156234396986065,
#  'w111wx': 0.00018156234396986065,
#  'subscribed': 0.00018156234396986065,
#  'content': 0.0006354682038945123,
#  '£3': 0.0005446870319095819,
#  '82324': 9.078117198493032e-05,
#  'helpline': 0.00013617175797739548,
#  '08706091795': 0.00013617175797739548,
#  '2004': 0.0003631246879397213,
#  '07xxxxxxxxx': 0.00018156234396986065,
#  '786': 0.0002269529299623258,
#  'unredeemed': 0.0002269529299623258,
#  '08719181259': 9.078117198493032e-05,
#  'xxxxx': 9.078117198493032e-05,
#  '26': 9.078117198493032e-05,
#  '03': 9.078117198493032e-05,
#  '05': 0.00018156234396986065,
#  'call2optout/hf8': 9.078117198493032e-05,
#  'a': 0.0008624211338568381,
#  'picture': 9.078117198493032e-05,
#  'also': 0.00018156234396986065,
#  '//alto18': 9.078117198493032e-05,
#  'uk/wave/wave': 9.078117198493032e-05,
#  'asp': 0.00013617175797739548,
#  'o=44345': 9.078117198493032e-05,
#  'summers': 9.078117198493032e-05,
#  'finally': 9.078117198493032e-05,
#  'singles': 0.00027234351595479097,
#  'yr': 0.0004539058599246516,
#  'area': 0.0004085152739321865,
#  'matched': 9.078117198493032e-05,
#  'summer': 0.0003631246879397213,
#  'help08714742804': 9.078117198493032e-05,
#  'realize': 9.078117198493032e-05,
#  '40': 0.00013617175797739548,
#  'years': 0.0003631246879397213,
#  "'ll": 0.00013617175797739548,
#  'thousands': 9.078117198493032e-05,
#  'old': 0.00013617175797739548,
#  'running': 9.078117198493032e-05,
#  'around': 0.00013617175797739548,
#  'tattoos': 9.078117198493032e-05,
#  'recently': 0.00013617175797739548,
#  'unable': 0.00013617175797739548,
#  'so': 0.00018156234396986065,
#  '07090298926': 9.078117198493032e-05,
#  're-schedule': 0.00013617175797739548,
#  'ref:9307622': 9.078117198493032e-05,
#  'information': 0.0004085152739321865,
#  'o2': 0.00031773410194725616,
#  'lucky': 0.0004085152739321865,
#  'why': 0.0003631246879397213,
#  'log': 0.0003631246879397213,
#  'onto': 0.0003631246879397213,
#  '//www': 0.0005446870319095819,
#  'urawinner': 0.00031773410194725616,
#  'there': 0.0003631246879397213,
#  'fantastic': 0.00031773410194725616,
#  'surprise': 0.00027234351595479097,
#  'representative': 0.0004992964459171168,
#  'mila': 0.00013617175797739548,
#  'age23': 0.00013617175797739548,
#  'blonde': 0.00013617175797739548,
#  'guys': 0.00031773410194725616,
#  'mtalk': 0.00013617175797739548,
#  '69866': 0.00013617175797739548,
#  '30pp/txt': 0.00013617175797739548,
#  '5free': 0.00013617175797739548,
#  'increments': 0.00013617175797739548,
#  'help08718728876': 0.00013617175797739548,
#  'burger': 0.00013617175797739548,
#  'king': 0.00013617175797739548,
#  'footy': 9.078117198493032e-05,
#  'stadium': 9.078117198493032e-05,
#  'sept': 0.00013617175797739548,
#  'large': 9.078117198493032e-05,
#  'super': 0.00018156234396986065,
#  'coca-cola': 9.078117198493032e-05,
#  'walk': 9.078117198493032e-05,
#  'gr8': 0.0003631246879397213,
#  'all': 0.00018156234396986065,
#  'mobs': 9.078117198493032e-05,
#  '2u': 9.078117198493032e-05,
#  'rply': 0.00018156234396986065,
#  'title': 9.078117198493032e-05,
#  'breathe1': 9.078117198493032e-05,
#  'titles': 9.078117198493032e-05,
#  'crazyin': 9.078117198493032e-05,
#  'sleepingwith': 9.078117198493032e-05,
#  'finest': 9.078117198493032e-05,
#  'ymca': 9.078117198493032e-05,
#  'pobox365o4w45wq': 9.078117198493032e-05,
#  '300p': 0.00013617175797739548,
#  '07742676969': 0.00013617175797739548,
#  '08719180248': 0.00013617175797739548,
#  '45239': 0.00018156234396986065,
#  'must': 0.0002269529299623258,
#  '89545': 0.00013617175797739548,
#  '4-tc': 0.00013617175797739548,
#  'biz': 0.00031773410194725616,
#  '2optout': 0.00018156234396986065,
#  '087187262701': 0.00013617175797739548,
#  '50gbp/mtmsg18': 0.00013617175797739548,
#  'txtauction': 0.00031773410194725616,
#  'time': 0.0006808587898869774,
#  'pound': 0.00027234351595479097,
#  '08712101358': 0.00013617175797739548,
#  '10p': 0.0006354682038945123,
#  'bt-national-rate': 0.0003631246879397213,
#  'funk': 9.078117198493032e-05,
#  'tones2u': 9.078117198493032e-05,
#  'original': 0.00018156234396986065,
#  'n': 0.0003631246879397213,
#  '3gbp': 0.00018156234396986065,
#  'operator': 0.0006354682038945123,
#  'rates': 0.0004085152739321865,
#  'ou': 9.078117198493032e-05,
#  '40gb': 0.00027234351595479097,
#  'ipod': 0.0004539058599246516,
#  'mp3': 0.0002269529299623258,
#  '83355': 0.00018156234396986065,
#  'ibhltd': 0.00018156234396986065,
#  'ldnw15h': 0.00018156234396986065,
#  '150p/mtmsgrcvd18': 0.00013617175797739548,
#  'promotion': 9.078117198493032e-05,
#  '8714714': 9.078117198493032e-05,
#  'city': 0.00013617175797739548,
#  'break': 0.00013617175797739548,
#  '£200': 0.0003631246879397213,
#  'shopping': 0.0003631246879397213,
#  'spree': 0.00031773410194725616,
#  'store': 0.00027234351595479097,
#  '88039': 0.00018156234396986065,
#  'skilgme': 0.00018156234396986065,
#  'tscs087147403231winawk': 0.00013617175797739548,
#  '50perwksub': 0.00013617175797739548,
#  '078498': 9.078117198493032e-05,
#  '7': 0.0002269529299623258,
#  '08719180219': 9.078117198493032e-05,
#  '06': 0.00013617175797739548,
#  '8077': 0.00013617175797739548,
#  'w45wq': 0.0002269529299623258,
#  'norm150p/tone': 0.0002269529299623258,
#  'rayman': 9.078117198493032e-05,
#  'golf': 9.078117198493032e-05,
#  'arcade': 0.0002269529299623258,
#  'settings': 0.00013617175797739548,
#  'post': 0.0002269529299623258,
#  'save': 0.00018156234396986065,
#  'activ8': 9.078117198493032e-05,
#  'press': 0.00013617175797739548,
#  '0': 0.00013617175797739548,
#  'key': 9.078117198493032e-05,
#  'termsapply': 9.078117198493032e-05,
#  'reminder': 0.00013617175797739548,
#  'downloaded': 9.078117198493032e-05,
#  'already': 9.078117198493032e-05,
#  'paid': 9.078117198493032e-05,
#  'goto': 0.00027234351595479097,
#  ...}

# %%
import random
# Create a list of all the sentences in the dataframe
sentences = test_df['text'].tolist()
classes=test_df['type'].tolist()
# Generate a random number between 0 and the number of sentences in the list
random_index = random.randint(0, len(sentences))

# Use the list index to access the sentence at the random index
random_sentence = sentences[random_index]
random_class =classes[random_index]

# Print the sentence
print(random_sentence +'"class"'+random_class)
# Out:
# st andre  virgil's cream"class"ham

# %%
# checking class of random selected sentence.
prob_test_spam=prob_spam
prob_test_ham=prob_ham
tokens = nltk.word_tokenize(random_sentence)
for token in tokens:
    if token in ham:
        prob_test_ham*=cond_prob_ham[token]
    else:
        prob_test_ham*=(1/(count_ham+vocab))
for token in tokens:
    if token in spam:
        prob_test_spam*=cond_prob_spam[token]
    else:
        prob_test_spam*=(1/(count_spam+vocab))
print("sentence taken: "+ random_sentence + " \n Belongs to class: "+ random_class)
print("probaility of sentence being ham: ")
print(prob_test_ham) 
print("Probablity of test being spam: ")
print(prob_test_spam)
if(prob_test_ham>prob_test_spam):
    print("Sentence predicted to be of class ham")
else:
    print("sentence predicted to be of class spam")
# Out:
# sentence taken: st andre  virgil's cream
#  Belongs to class: ham
# probaility of sentence being ham:
# 2.0222482420077829e-19
# Probablity of test being spam:
# 1.1332583553985182e-20
# Sentence predicted to be of class ham

# %%
true_ham=0
true_spam=0
false_ham=0
false_spam=0
for type1,sentence in test_df.iterrows():
    stri=sentence['text']
    class_og= sentence['type']
    prob_test_spam=prob_spam
    prob_test_ham=prob_ham
    tokens = nltk.word_tokenize(stri)
    for token in tokens:
        if token in ham:
            prob_test_ham*=cond_prob_ham[token]
        else:
            prob_test_ham*=(1/(count_ham+vocab))
    for token in tokens:
        if token in spam:
            prob_test_spam*=cond_prob_spam[token]
        else:
            prob_test_spam*=(1/(count_spam+vocab))
    if(prob_test_ham>prob_test_spam):
        if(class_og=='ham'):
            true_ham+=1
        else:
            false_ham+=1
    else:
        if(class_og=='spam'):
            true_spam+=1
        else:
            false_spam+=1

# %%
accuracy=(true_spam+true_ham)/(true_ham+true_spam+false_spam+false_ham)
accuracy
# Out:
# 0.96415770609319
